# %% [markdown]
# [![Roboflow Notebooks](https://media.roboflow.com/notebooks/template/bannertest2-2.png?ik-sdk-version=javascript-1.4.3&updatedAt=1672932710194)](https://github.com/roboflow/notebooks)
#
# # How to Train RF-DETR Object Detection on a Custom Dataset
#
# ---
#
# [![hf space](https://img.shields.io/badge/%F0%9F%A4%97%20Hugging%20Face-Spaces-blue)](https://huggingface.co/spaces/SkalskiP/RF-DETR)
# [![colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/roboflow-ai/notebooks/blob/main/notebooks/how-to-finetune-rf-detr-on-detection-dataset.ipynb)
# [![roboflow](https://raw.githubusercontent.com/roboflow-ai/notebooks/main/assets/badges/roboflow-blogpost.svg)](https://blog.roboflow.com/rf-detr)
# [![code](https://badges.aleen42.com/src/github.svg)](https://github.com/roboflow/rf-detr)
#
# RF-DETR is a real-time transformer architecture for object detection and instance segmentation developed by Roboflow. Built on a DINOv2 vision transformer backbone, RF-DETR delivers state-of-the-art accuracy and latency trade-offs on [Microsoft COCO](https://cocodataset.org/#home) and [RF100-VL](https://github.com/roboflow/rf100-vl).
#
# RF-DETR uses a DINOv2 vision transformer backbone and supports both detection and instance segmentation in a single, consistent API. All core models and code are released under the Apache 2.0 license.
#
# <img alt="rf_detr_1-4_latency_accuracy_object_detection" src="https://storage.googleapis.com/com-roboflow-marketing/rf-detr/rf_detr_1-4_latency_accuracy_object_detection.png" />

# %% [markdown]
# ## Environment setup

# %% [markdown]
# ### Configure API Key
#
# To fine-tune RF-DETR, you need to provide your Roboflow API key. Follow these steps:
#
# - Go to your [`Roboflow Settings`](https://app.roboflow.com/settings/api) page. Click `Copy` to copy your private API key.
# - In Colab, go to the left pane and click on `Secrets` (🔑).
#     - Store your Roboflow API Key under the name `ROBOFLOW_API_KEY`.

# %%
import os
from google.colab import userdata

os.environ["ROBOFLOW_API_KEY"] = userdata.get("ROBOFLOW_API_KEY")

# %% [markdown]
# ### Check GPU availability
#
# Let's make sure that we have access to GPU. We can use `nvidia-smi` command to do that. In case of any problems navigate to `Edit` -> `Notebook settings` -> `Hardware accelerator`, set it to `T4 GPU`, and then click `Save`.

# %%
# !nvidia-smi
# Out:
# Thu Jan 22 19:16:44 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA L4                      Off |   00000000:00:03.0 Off |                    0 |
# | N/A   38C    P8             11W /   72W |       0MiB /  23034MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %% [markdown]
# ### Install dependencies
#
# Installs RF-DETR version 1.4.0 or higher, along with Supervision for benchmarking and Roboflow for pulling datasets and uploading models to the Roboflow platform.

# %%
# !pip install -q rfdetr>=1.4.0 supervision roboflow

# %% [markdown]
# ### Download example data
#
# Downloads example images for testing. You can use these or replace them with your own images.

# %%
# !wget -q https://media.roboflow.com/notebooks/examples/dog-2.jpeg
# !wget -q https://media.roboflow.com/notebooks/examples/dog-3.jpeg

# %% [markdown]
# ## Inference with Pre-trained COCO Model
#
# Runs inference on an example image using a pretrained RF-DETR Medium model (trained on COCO). To use a different model size, simply replace `RFDETRMedium` with `RFDETRNano`, `RFDETRSmall`, `RFDETRBase` or `RFDETRLarge` as needed.

# %%
import numpy as np
import supervision as sv

from PIL import Image

from rfdetr import RFDETRMedium
from rfdetr.util.coco_classes import COCO_CLASSES

image = Image.open("dog-2.jpeg")

model = RFDETRMedium(resolution=640)
model.optimize_for_inference()

detections = model.predict(image, threshold=0.5)

color = sv.ColorPalette.from_hex([
    "#ffff00", "#ff9b00", "#ff8080", "#ff66b2", "#ff66ff", "#b266ff",
    "#9999ff", "#3399ff", "#66ffff", "#33ff99", "#66ff66", "#99ff00"
])
text_scale = sv.calculate_optimal_text_scale(resolution_wh=image.size)
thickness = sv.calculate_optimal_line_thickness(resolution_wh=image.size)

bbox_annotator = sv.BoxAnnotator(color=color, thickness=thickness)
label_annotator = sv.LabelAnnotator(
    color=color,
    text_color=sv.Color.BLACK,
    text_scale=text_scale,
    smart_position=True
)

labels = [
    f"{COCO_CLASSES[class_id]} {confidence:.2f}"
    for class_id, confidence
    in zip(detections.class_id, detections.confidence)
]

annotated_image = image.copy()
annotated_image = bbox_annotator.annotate(annotated_image, detections)
annotated_image = label_annotator.annotate(annotated_image, detections, labels)
annotated_image.thumbnail((800, 800))
annotated_image
# Out:
# Using a different number of positional encodings than DINOv2, which means we're not loading DINOv2 backbone weights. This is not a problem if finetuning a pretrained RF-DETR model.
# Using patch size 16 instead of 14, which means we're not loading DINOv2 backbone weights. This is not a problem if finetuning a pretrained RF-DETR model.
# Loading pretrain weights
# <PIL.Image.Image image mode=RGB size=450x800>

# %% [markdown]
# ## Download Dataset from Roboflow Universe
#
# RF-DETR expects the dataset to be in COCO format. Divide your dataset into three subdirectories: `train`, `valid`, and `test`. Each subdirectory should contain its own `_annotations.coco.json` file that holds the annotations for that particular split, along with the corresponding image files. Below is an example of the directory structure:
#
# ```
# dataset/
# ├── train/
# │   ├── _annotations.coco.json
# │   ├── image1.jpg
# │   ├── image2.jpg
# │   └── ... (other image files)
# ├── valid/
# │   ├── _annotations.coco.json
# │   ├── image1.jpg
# │   ├── image2.jpg
# │   └── ... (other image files)
# └── test/
#     ├── _annotations.coco.json
#     ├── image1.jpg
#     ├── image2.jpg
#     └── ... (other image files)
# ```
#
# [Roboflow](https://roboflow.com/annotate) allows you to create object detection datasets from scratch or convert existing datasets from formats like YOLO, and then export them in COCO JSON format for training. You can also explore [Roboflow Universe](https://universe.roboflow.com/) to find pre-labeled datasets for a range of use cases.

# %%
from roboflow import download_dataset

dataset = download_dataset("https://universe.roboflow.com/roboflow-jvuqo/basketball-player-detection-2/13", "coco")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# Downloading Dataset Version Zip in basketball-player-detection-2-13 to coco:: 100%|██████████| 122781/122781 [00:07<00:00, 16080.21it/s]
# Extracting Dataset Version Zip to basketball-player-detection-2-13 in coco:: 100%|██████████| 1406/1406 [00:00<00:00, 4046.39it/s]

# %% [markdown]
# ## Train RF-DETR on custom dataset
#
# ### Choose the right `batch_size`
#
# Different GPUs have different amounts of VRAM (video memory), which limits how much data they can handle at once during training. To make training work well on any machine, you can adjust two settings: `batch_size` and `grad_accum_steps`. These control how many samples are processed at a time. The key is to keep their product equal to 16 — that’s our recommended total batch size. For example, on powerful GPUs like the A100, set `batch_size=16` and `grad_accum_steps=1`. On smaller GPUs like the T4, use `batch_size=4` and `grad_accum_steps=4`. We use a method called gradient accumulation, which lets the model simulate training with a larger batch size by gradually collecting updates before adjusting the weights.

# %%
from rfdetr import RFDETRNano

model = RFDETRNano()

model.train(dataset_dir=dataset.location, epochs=10, batch_size=8, grad_accum_steps=2)
# Out:
# Using a different number of positional encodings than DINOv2, which means we're not loading DINOv2 backbone weights. This is not a problem if finetuning a pretrained RF-DETR model.
# Using patch size 16 instead of 14, which means we're not loading DINOv2 backbone weights. This is not a problem if finetuning a pretrained RF-DETR model.
# Loading pretrain weights
# Failed to load pretrain weights: PytorchStreamReader failed reading zip archive: failed finding central directory
# Failed to load pretrain weights, re-downloading
# rf-detr-nano.pth: 100%|██████████| 349M/349M [00:16<00:00, 22.1MiB/s]
# TensorBoard logging initialized. To monitor logs, use 'tensorboard --logdir output' and open http://localhost:6006/ in browser.
# Not using distributed mode
# git:
#   sha: N/A, status: clean, branch: N/A
#
# Namespace(num_classes=6, grad_accum_steps=2, amp=True, lr=0.0001, lr_encoder=0.00015, batch_size=8, weight_decay=0.0001, epochs=10, lr_drop=100, clip_max_norm=0.1, lr_vit_layer_decay=0.8, lr_component_decay=0.7, do_benchmark=False, dropout=0, drop_path=0.0, drop_mode='standard', drop_schedule='constant', cutoff_epoch=0, pretrained_encoder=None, pretrain_weights='rf-detr-nano.pth', pretrain_exclude_keys=None, pretrain_keys_modify_to_load=None, pretrained_distiller=None, encoder='dinov2_windowed_small', vit_encoder_num_layers=12, window_block_indexes=None, position_embedding='sine', out_feature_indexes=[3, 6, 9, 12], freeze_encoder=False, layer_norm=True, rms_norm=False, backbone_lora=False, force_no_pretrain=False, dec_layers=2, dim_feedforward=2048, hidden_dim=256, sa_nheads=8, ca_nheads=16, num_queries=300, group_detr=13, two_stage=True, projector_scale=['P4'], lite_refpoint_refine=True, num_select=300, dec_n_points=2, decoder_norm='LN', bbox_reparam=True, freeze_batch_norm=False, set_cost_class=2, set_cost_bbox=5, set_cost_giou=2, cls_loss_coef=1.0, bbox_loss_coef=5, giou_loss_coef=2, focal_alpha=0.25, aux_loss=True, sum_group_losses=False, use_varifocal_loss=False, use_position_supervised_loss=False, ia_bce_loss=True, dataset_file='roboflow', coco_path=None, dataset_dir='/content/basketball-player-detection-2-13', square_resize_div_64=True, output_dir='output', dont_save_weights=False, checkpoint_interval=10, seed=42, resume=None, start_epoch=0, eval=False, use_ema=True, ema_decay=0.993, ema_tau=100, num_workers=2, device='cuda', world_size=1, dist_url='env://', sync_bn=True, fp16_eval=False, encoder_only=False, backbone_only=False, resolution=384, use_cls_token=False, multi_scale=True, expanded_scales=True, do_random_resize_via_padding=False, warmup_epochs=0.0, lr_scheduler='step', lr_min_factor=0.0, early_stopping=False, early_stopping_patience=10, early_stopping_min_delta=0.001, early_stopping_use_ema=False, gradient_checkpointing=False, patch_size=16, num_windows=2, positional_encoding_size=24, mask_downsample_ratio=4, license='Apache-2.0', tensorboard=True, wandb=False, project=None, run=None, class_names=['ball', 'number', 'player', 'referee', 'rim'], run_test=True, segmentation_head=False, eval_max_dets=500, distributed=False)
# number of params: 30161468
# [544]
# loading annotations into memory...
# Done (t=0.05s)
# creating index...
# index created!
# [544]
# loading annotations into memory...
# Done (t=0.01s)
# creating index...
# index created!
# [544]
# loading annotations into memory...
# Done (t=0.01s)
# creating index...
# index created!
# Get benchmark
# Start training
# Grad accum steps:  2
# Total batch size:  16
# LENGTH OF DATA LOADER: 65
# Using a non-tuple sequence for multidimensional indexing is deprecated and will be changed in pytorch 2.9; use x[tuple(seq)] instead of x[seq]. In pytorch 2.9 this will be interpreted as tensor index, x[torch.tensor(seq)], which will result either in an error or a different result (Triggered internally at /pytorch/torch/csrc/autograd/python_variable_indexing.cpp:306.)
# Using a non-tuple sequence for multidimensional indexing is deprecated and will be changed in pytorch 2.9; use x[tuple(seq)] instead of x[seq]. In pytorch 2.9 this will be interpreted as tensor index, x[torch.tensor(seq)], which will result either in an error or a different result (Triggered internally at /pytorch/torch/csrc/autograd/python_variable_indexing.cpp:306.)
# Using a non-tuple sequence for multidimensional indexing is deprecated and will be changed in pytorch 2.9; use x[tuple(seq)] instead of x[seq]. In pytorch 2.9 this will be interpreted as tensor index, x[torch.tensor(seq)], which will result either in an error or a different result (Triggered internally at /pytorch/torch/csrc/autograd/python_variable_indexing.cpp:306.)
# Epoch: [0]  [ 0/65]  eta: 0:02:21  lr: 0.000100  class_error: 93.83  loss: 7.6190 (7.6190)  loss_ce: 1.1873 (1.1873)  loss_bbox: 0.3462 (0.3462)  loss_giou: 0.9597 (0.9597)  loss_ce_0: 1.1472 (1.1472)  loss_bbox_0: 0.3870 (0.3870)  loss_giou_0: 0.9851 (0.9851)  loss_ce_enc: 1.2261 (1.2261)  loss_bbox_enc: 0.3759 (0.3759)  loss_giou_enc: 1.0045 (1.0045)  loss_ce_unscaled: 1.1873 (1.1873)  class_error_unscaled: 93.8344 (93.8344)  loss_bbox_unscaled: 0.0692 (0.0692)  loss_giou_unscaled: 0.4799 (0.4799)  cardinality_error_unscaled: 3882.2500 (3882.2500)  loss_ce_0_unscaled: 1.1472 (1.1472)  loss_bbox_0_unscaled: 0.0774 (0.0774)  loss_giou_0_unscaled: 0.4925 (0.4925)  cardinality_error_0_unscaled: 3883.6250 (3883.6250)  loss_ce_enc_unscaled: 1.2261 (1.2261)  loss_bbox_enc_unscaled: 0.0752 (0.0752)  loss_giou_enc_unscaled: 0.5023 (0.5023)  cardinality_error_enc_unscaled: 3883.6250 (3883.6250)  time: 2.1773  data: 0.6572  max mem: 3708
# Epoch: [0]  [10/65]  eta: 0:00:52  lr: 0.000100  class_error: 50.31  loss: 6.3589 (6.2773)  loss_ce: 0.8247 (0.8557)  loss_bbox: 0.2922 (0.2722)  loss_giou: 0.9364 (0.9083)  loss_ce_0: 0.8087 (0.8444)  loss_bbox_0: 0.3177 (0.2954)  loss_giou_0: 0.9731 (0.9384)  loss_ce_enc: 0.8018 (0.8387)  loss_bbox_enc: 0.3166 (0.3271)  loss_giou_enc: 1.0045 (0.9971)  loss_ce_unscaled: 0.8247 (0.8557)  class_error_unscaled: 50.3077 (64.0351)  loss_bbox_unscaled: 0.0584 (0.0544)  loss_giou_unscaled: 0.4682 (0.4542)  cardinality_error_unscaled: 3881.5000 (3879.8750)  loss_ce_0_unscaled: 0.8087 (0.8444)  loss_bbox_0_unscaled: 0.0635 (0.0591)  loss_giou_0_unscaled: 0.4865 (0.4692)  cardinality_error_0_unscaled: 3881.5000 (3881.8864)  loss_ce_enc_unscaled: 0.8018 (0.8387)  loss_bbox_enc_unscaled: 0.0633 (0.0654)  loss_giou_enc_unscaled: 0.5023 (0.4985)  cardinality_error_enc_unscaled: 3881.3750 (3757.8409)  time: 0.9593  data: 0.0947  max mem: 4838
# Epoch: [0]  [20/65]  eta: 0:00:40  lr: 0.000100  class_error: 21.07  loss: 5.3995 (5.8008)  loss_ce: 0.7622 (0.7959)  loss_bbox: 0.1993 (0.2351)  loss_giou: 0.8210 (0.8567)  loss_ce_0: 0.7770 (0.7918)  loss_bbox_0: 0.2153 (0.2496)  loss_giou_0: 0.8217 (0.8771)  loss_ce_enc: 0.7633 (0.7847)  loss_bbox_enc: 0.2333 (0.2802)  loss_giou_enc: 0.8707 (0.9297)  loss_ce_unscaled: 0.7622 (0.7959)  class_error_unscaled: 48.6486 (52.6685)  loss_bbox_unscaled: 0.0399 (0.0470)  loss_giou_unscaled: 0.4105 (0.4284)  cardinality_error_unscaled: 3875.0000 (3873.6131)  loss_ce_0_unscaled: 0.7770 (0.7918)  loss_bbox_0_unscaled: 0.0431 (0.0499)  loss_giou_0_unscaled: 0.4108 (0.4386)  cardinality_error_0_unscaled: 3879.8750 (3878.8393)  loss_ce_enc_unscaled: 0.7633 (0.7847)  loss_bbox_enc_unscaled: 0.0467 (0.0560)  loss_giou_enc_unscaled: 0.4353 (0.4648)  cardinality_error_enc_unscaled: 3871.2500 (3782.1131)  time: 0.8374  data: 0.0391  max mem: 4992
# Epoch: [0]  [30/65]  eta: 0:00:30  lr: 0.000100  class_error: 17.72  loss: 5.0730 (5.5685)  loss_ce: 0.7171 (0.7702)  loss_bbox: 0.1751 (0.2181)  loss_giou: 0.7479 (0.8240)  loss_ce_0: 0.7151 (0.7686)  loss_bbox_0: 0.1773 (0.2320)  loss_giou_0: 0.7786 (0.8433)  loss_ce_enc: 0.7062 (0.7595)  loss_bbox_enc: 0.2231 (0.2602)  loss_giou_enc: 0.8413 (0.8927)  loss_ce_unscaled: 0.7171 (0.7702)  class_error_unscaled: 22.7982 (41.7879)  loss_bbox_unscaled: 0.0350 (0.0436)  loss_giou_unscaled: 0.3739 (0.4120)  cardinality_error_unscaled: 3833.2500 (3791.4839)  loss_ce_0_unscaled: 0.7151 (0.7686)  loss_bbox_0_unscaled: 0.0355 (0.0464)  loss_giou_0_unscaled: 0.3893 (0.4216)  cardinality_error_0_unscaled: 3857.5000 (3820.5968)  loss_ce_enc_unscaled: 0.7062 (0.7595)  loss_bbox_enc_unscaled: 0.0446 (0.0520)  loss_giou_enc_unscaled: 0.4206 (0.4463)  cardinality_error_enc_unscaled: 3848.5000 (3762.9234)  time: 0.8290  data: 0.0422  max mem: 5044
# Epoch: [0]  [40/65]  eta: 0:00:21  lr: 0.000100  class_error: 7.86  loss: 4.6869 (5.3544)  loss_ce: 0.6781 (0.7445)  loss_bbox: 0.1445 (0.2037)  loss_giou: 0.6869 (0.7934)  loss_ce_0: 0.7068 (0.7482)  loss_bbox_0: 0.1501 (0.2169)  loss_giou_0: 0.7062 (0.8122)  loss_ce_enc: 0.6952 (0.7391)  loss_bbox_enc: 0.1766 (0.2401)  loss_giou_enc: 0.7340 (0.8564)  loss_ce_unscaled: 0.6781 (0.7445)  class_error_unscaled: 16.5680 (34.9666)  loss_bbox_unscaled: 0.0289 (0.0407)  loss_giou_unscaled: 0.3434 (0.3967)  cardinality_error_unscaled: 3156.0000 (3580.9482)  loss_ce_0_unscaled: 0.7068 (0.7482)  loss_bbox_0_unscaled: 0.0300 (0.0434)  loss_giou_0_unscaled: 0.3531 (0.4061)  cardinality_error_0_unscaled: 3378.7500 (3643.5122)  loss_ce_enc_unscaled: 0.6952 (0.7391)  loss_bbox_enc_unscaled: 0.0353 (0.0480)  loss_giou_enc_unscaled: 0.3670 (0.4282)  cardinality_error_enc_unscaled: 3528.2500 (3632.9268)  time: 0.8193  data: 0.0427  max mem: 5119
# Epoch: [0]  [50/65]  eta: 0:00:12  lr: 0.000100  class_error: 3.89  loss: 4.5952 (5.2172)  loss_ce: 0.6552 (0.7257)  loss_bbox: 0.1332 (0.1946)  loss_giou: 0.6502 (0.7764)  loss_ce_0: 0.6789 (0.7332)  loss_bbox_0: 0.1419 (0.2079)  loss_giou_0: 0.6605 (0.7950)  loss_ce_enc: 0.6650 (0.7232)  loss_bbox_enc: 0.1633 (0.2270)  loss_giou_enc: 0.7131 (0.8340)  loss_ce_unscaled: 0.6552 (0.7257)  class_error_unscaled: 11.2266 (30.0682)  loss_bbox_unscaled: 0.0266 (0.0389)  loss_giou_unscaled: 0.3251 (0.3882)  cardinality_error_unscaled: 2982.2500 (3501.8333)  loss_ce_0_unscaled: 0.6789 (0.7332)  loss_bbox_0_unscaled: 0.0284 (0.0416)  loss_giou_0_unscaled: 0.3303 (0.3975)  cardinality_error_0_unscaled: 3076.3750 (3541.2279)  loss_ce_enc_unscaled: 0.6650 (0.7232)  loss_bbox_enc_unscaled: 0.0327 (0.0454)  loss_giou_enc_unscaled: 0.3566 (0.4170)  cardinality_error_enc_unscaled: 3333.7500 (3541.0956)  time: 0.8251  data: 0.0392  max mem: 5119
# Epoch: [0]  [60/65]  eta: 0:00:04  lr: 0.000100  class_error: 6.59  loss: 4.4935 (5.1136)  loss_ce: 0.6390 (0.7103)  loss_bbox: 0.1420 (0.1884)  loss_giou: 0.6823 (0.7643)  loss_ce_0: 0.6562 (0.7206)  loss_bbox_0: 0.1504 (0.2012)  loss_giou_0: 0.6839 (0.7822)  loss_ce_enc: 0.6454 (0.7091)  loss_bbox_enc: 0.1700 (0.2191)  loss_giou_enc: 0.7226 (0.8184)  loss_ce_unscaled: 0.6390 (0.7103)  class_error_unscaled: 7.7991 (26.5967)  loss_bbox_unscaled: 0.0284 (0.0377)  loss_giou_unscaled: 0.3412 (0.3821)  cardinality_error_unscaled: 3469.1250 (3518.7930)  loss_ce_0_unscaled: 0.6562 (0.7206)  loss_bbox_0_unscaled: 0.0301 (0.0402)  loss_giou_0_unscaled: 0.3420 (0.3911)  cardinality_error_0_unscaled: 3347.2500 (3542.4570)  loss_ce_enc_unscaled: 0.6454 (0.7091)  loss_bbox_enc_unscaled: 0.0340 (0.0438)  loss_giou_enc_unscaled: 0.3613 (0.4092)  cardinality_error_enc_unscaled: 3415.7500 (3521.8934)  time: 0.8181  data: 0.0376  max mem: 5119
# Epoch: [0]  [64/65]  eta: 0:00:00  lr: 0.000100  class_error: 3.77  loss: 4.4562 (5.0440)  loss_ce: 0.6331 (0.7034)  loss_bbox: 0.1325 (0.1837)  loss_giou: 0.6675 (0.7536)  loss_ce_0: 0.6507 (0.7149)  loss_bbox_0: 0.1423 (0.1957)  loss_giou_0: 0.6722 (0.7703)  loss_ce_enc: 0.6382 (0.7032)  loss_bbox_enc: 0.1684 (0.2131)  loss_giou_enc: 0.7200 (0.8060)  loss_ce_unscaled: 0.6331 (0.7034)  class_error_unscaled: 6.5505 (25.2056)  loss_bbox_unscaled: 0.0265 (0.0367)  loss_giou_unscaled: 0.3337 (0.3768)  cardinality_error_unscaled: 3498.7500 (3516.4577)  loss_ce_0_unscaled: 0.6507 (0.7149)  loss_bbox_0_unscaled: 0.0285 (0.0391)  loss_giou_0_unscaled: 0.3361 (0.3852)  cardinality_error_0_unscaled: 3490.5000 (3538.6769)  loss_ce_enc_unscaled: 0.6382 (0.7032)  loss_bbox_enc_unscaled: 0.0337 (0.0426)  loss_giou_enc_unscaled: 0.3600 (0.4030)  cardinality_error_enc_unscaled: 3521.7500 (3521.6923)  time: 0.8312  data: 0.0377  max mem: 5119
# Epoch: [0] Total time: 0:00:55 (0.8511 s / it)
# Averaged stats: lr: 0.000100  class_error: 3.77  loss: 4.4562 (5.0440)  loss_ce: 0.6331 (0.7034)  loss_bbox: 0.1325 (0.1837)  loss_giou: 0.6675 (0.7536)  loss_ce_0: 0.6507 (0.7149)  loss_bbox_0: 0.1423 (0.1957)  loss_giou_0: 0.6722 (0.7703)  loss_ce_enc: 0.6382 (0.7032)  loss_bbox_enc: 0.1684 (0.2131)  loss_giou_enc: 0.7200 (0.8060)  loss_ce_unscaled: 0.6331 (0.7034)  class_error_unscaled: 6.5505 (25.2056)  loss_bbox_unscaled: 0.0265 (0.0367)  loss_giou_unscaled: 0.3337 (0.3768)  cardinality_error_unscaled: 3498.7500 (3516.4577)  loss_ce_0_unscaled: 0.6507 (0.7149)  loss_bbox_0_unscaled: 0.0285 (0.0391)  loss_giou_0_unscaled: 0.3361 (0.3852)  cardinality_error_0_unscaled: 3490.5000 (3538.6769)  loss_ce_enc_unscaled: 0.6382 (0.7032)  loss_bbox_enc_unscaled: 0.0337 (0.0426)  loss_giou_enc_unscaled: 0.3600 (0.4030)  cardinality_error_enc_unscaled: 3521.7500 (3521.6923)
# Test:  [ 0/24]  eta: 0:00:12  class_error: 5.81  loss: 4.2701 (4.2701)  loss_ce: 0.6016 (0.6016)  loss_bbox: 0.1204 (0.1204)  loss_giou: 0.6726 (0.6726)  loss_ce_0: 0.6289 (0.6289)  loss_bbox_0: 0.1282 (0.1282)  loss_giou_0: 0.6760 (0.6760)  loss_ce_enc: 0.6211 (0.6211)  loss_bbox_enc: 0.1363 (0.1363)  loss_giou_enc: 0.6849 (0.6849)  loss_ce_unscaled: 0.6016 (0.6016)  class_error_unscaled: 5.8065 (5.8065)  loss_bbox_unscaled: 0.0241 (0.0241)  loss_giou_unscaled: 0.3363 (0.3363)  cardinality_error_unscaled: 239.7500 (239.7500)  loss_ce_0_unscaled: 0.6289 (0.6289)  loss_bbox_0_unscaled: 0.0256 (0.0256)  loss_giou_0_unscaled: 0.3380 (0.3380)  cardinality_error_0_unscaled: 235.1250 (235.1250)  loss_ce_enc_unscaled: 0.6211 (0.6211)  loss_bbox_enc_unscaled: 0.0273 (0.0273)  loss_giou_enc_unscaled: 0.3425 (0.3425)  cardinality_error_enc_unscaled: 246.1250 (246.1250)  time: 0.5380  data: 0.2485  max mem: 5119
# Test:  [10/24]  eta: 0:00:03  class_error: 4.67  loss: 4.2898 (4.3135)  loss_ce: 0.6211 (0.6154)  loss_bbox: 0.1263 (0.1337)  loss_giou: 0.6674 (0.6594)  loss_ce_0: 0.6445 (0.6445)  loss_bbox_0: 0.1296 (0.1379)  loss_giou_0: 0.6665 (0.6567)  loss_ce_enc: 0.6250 (0.6264)  loss_bbox_enc: 0.1470 (0.1488)  loss_giou_enc: 0.7005 (0.6906)  loss_ce_unscaled: 0.6211 (0.6154)  class_error_unscaled: 5.2980 (5.5352)  loss_bbox_unscaled: 0.0253 (0.0267)  loss_giou_unscaled: 0.3337 (0.3297)  cardinality_error_unscaled: 246.2500 (246.8636)  loss_ce_0_unscaled: 0.6445 (0.6445)  loss_bbox_0_unscaled: 0.0259 (0.0276)  loss_giou_0_unscaled: 0.3332 (0.3283)  cardinality_error_0_unscaled: 242.5000 (242.7045)  loss_ce_enc_unscaled: 0.6250 (0.6264)  loss_bbox_enc_unscaled: 0.0294 (0.0298)  loss_giou_enc_unscaled: 0.3503 (0.3453)  cardinality_error_enc_unscaled: 249.5000 (250.9432)  time: 0.2807  data: 0.0446  max mem: 5119
# Test:  [20/24]  eta: 0:00:01  class_error: 7.91  loss: 4.3035 (4.3319)  loss_ce: 0.6211 (0.6213)  loss_bbox: 0.1263 (0.1300)  loss_giou: 0.6526 (0.6598)  loss_ce_0: 0.6445 (0.6473)  loss_bbox_0: 0.1305 (0.1346)  loss_giou_0: 0.6641 (0.6617)  loss_ce_enc: 0.6406 (0.6321)  loss_bbox_enc: 0.1475 (0.1485)  loss_giou_enc: 0.7005 (0.6966)  loss_ce_unscaled: 0.6211 (0.6213)  class_error_unscaled: 5.7971 (6.2799)  loss_bbox_unscaled: 0.0253 (0.0260)  loss_giou_unscaled: 0.3263 (0.3299)  cardinality_error_unscaled: 247.0000 (247.7917)  loss_ce_0_unscaled: 0.6445 (0.6473)  loss_bbox_0_unscaled: 0.0261 (0.0269)  loss_giou_0_unscaled: 0.3320 (0.3309)  cardinality_error_0_unscaled: 242.5000 (243.4881)  loss_ce_enc_unscaled: 0.6406 (0.6321)  loss_bbox_enc_unscaled: 0.0295 (0.0297)  loss_giou_enc_unscaled: 0.3503 (0.3483)  cardinality_error_enc_unscaled: 250.0000 (252.0714)  time: 0.2806  data: 0.0243  max mem: 5119
# Test:  [23/24]  eta: 0:00:00  class_error: 0.00  loss: 4.2981 (4.3311)  loss_ce: 0.6250 (0.6190)  loss_bbox: 0.1263 (0.1306)  loss_giou: 0.6526 (0.6618)  loss_ce_0: 0.6445 (0.6463)  loss_bbox_0: 0.1305 (0.1353)  loss_giou_0: 0.6558 (0.6629)  loss_ce_enc: 0.6328 (0.6297)  loss_bbox_enc: 0.1465 (0.1480)  loss_giou_enc: 0.7004 (0.6975)  loss_ce_unscaled: 0.6250 (0.6190)  class_error_unscaled: 5.7554 (5.9962)  loss_bbox_unscaled: 0.0253 (0.0261)  loss_giou_unscaled: 0.3263 (0.3309)  cardinality_error_unscaled: 245.8750 (246.9635)  loss_ce_0_unscaled: 0.6445 (0.6463)  loss_bbox_0_unscaled: 0.0261 (0.0271)  loss_giou_0_unscaled: 0.3279 (0.3314)  cardinality_error_0_unscaled: 240.5000 (242.6406)  loss_ce_enc_unscaled: 0.6328 (0.6297)  loss_bbox_enc_unscaled: 0.0293 (0.0296)  loss_giou_enc_unscaled: 0.3502 (0.3487)  cardinality_error_enc_unscaled: 249.5000 (251.1771)  time: 0.2731  data: 0.0232  max mem: 5119
# Test: Total time: 0:00:06 (0.2849 s / it)
# Averaged stats: class_error: 0.00  loss: 4.2981 (4.3311)  loss_ce: 0.6250 (0.6190)  loss_bbox: 0.1263 (0.1306)  loss_giou: 0.6526 (0.6618)  loss_ce_0: 0.6445 (0.6463)  loss_bbox_0: 0.1305 (0.1353)  loss_giou_0: 0.6558 (0.6629)  loss_ce_enc: 0.6328 (0.6297)  loss_bbox_enc: 0.1465 (0.1480)  loss_giou_enc: 0.7004 (0.6975)  loss_ce_unscaled: 0.6250 (0.6190)  class_error_unscaled: 5.7554 (5.9962)  loss_bbox_unscaled: 0.0253 (0.0261)  loss_giou_unscaled: 0.3263 (0.3309)  cardinality_error_unscaled: 245.8750 (246.9635)  loss_ce_0_unscaled: 0.6445 (0.6463)  loss_bbox_0_unscaled: 0.0261 (0.0271)  loss_giou_0_unscaled: 0.3279 (0.3314)  cardinality_error_0_unscaled: 240.5000 (242.6406)  loss_ce_enc_unscaled: 0.6328 (0.6297)  loss_bbox_enc_unscaled: 0.0293 (0.0296)  loss_giou_enc_unscaled: 0.3502 (0.3487)  cardinality_error_enc_unscaled: 249.5000 (251.1771)
# Accumulating evaluation results...
# DONE (t=0.33s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=500 ] = 0.270
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=500 ] = 0.517
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=500 ] = 0.261
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=500 ] = 0.149
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=500 ] = 0.583
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=500 ] = 0.315
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.131
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.358
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=500 ] = 0.381
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=500 ] = 0.336
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=500 ] = 0.684
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=500 ] = 0.505
# Mean of empty slice
# Mean of empty slice
# Mean of empty slice
# Test:  [ 0/24]  eta: 0:00:12  class_error: 5.81  loss: 4.2541 (4.2541)  loss_ce: 0.6016 (0.6016)  loss_bbox: 0.1197 (0.1197)  loss_giou: 0.6705 (0.6705)  loss_ce_0: 0.6289 (0.6289)  loss_bbox_0: 0.1279 (0.1279)  loss_giou_0: 0.6642 (0.6642)  loss_ce_enc: 0.6172 (0.6172)  loss_bbox_enc: 0.1327 (0.1327)  loss_giou_enc: 0.6914 (0.6914)  loss_ce_unscaled: 0.6016 (0.6016)  class_error_unscaled: 5.8065 (5.8065)  loss_bbox_unscaled: 0.0239 (0.0239)  loss_giou_unscaled: 0.3353 (0.3353)  cardinality_error_unscaled: 243.2500 (243.2500)  loss_ce_0_unscaled: 0.6289 (0.6289)  loss_bbox_0_unscaled: 0.0256 (0.0256)  loss_giou_0_unscaled: 0.3321 (0.3321)  cardinality_error_0_unscaled: 239.3750 (239.3750)  loss_ce_enc_unscaled: 0.6172 (0.6172)  loss_bbox_enc_unscaled: 0.0265 (0.0265)  loss_giou_enc_unscaled: 0.3457 (0.3457)  cardinality_error_enc_unscaled: 247.8750 (247.8750)  time: 0.5350  data: 0.2424  max mem: 5119
# Test:  [10/24]  eta: 0:00:04  class_error: 3.74  loss: 4.2631 (4.3037)  loss_ce: 0.6094 (0.6101)  loss_bbox: 0.1246 (0.1325)  loss_giou: 0.6705 (0.6619)  loss_ce_0: 0.6406 (0.6392)  loss_bbox_0: 0.1307 (0.1386)  loss_giou_0: 0.6648 (0.6584)  loss_ce_enc: 0.6250 (0.6225)  loss_bbox_enc: 0.1476 (0.1489)  loss_giou_enc: 0.6966 (0.6915)  loss_ce_unscaled: 0.6094 (0.6101)  class_error_unscaled: 5.0000 (4.9992)  loss_bbox_unscaled: 0.0249 (0.0265)  loss_giou_unscaled: 0.3353 (0.3310)  cardinality_error_unscaled: 249.3750 (250.4205)  loss_ce_0_unscaled: 0.6406 (0.6392)  loss_bbox_0_unscaled: 0.0261 (0.0277)  loss_giou_0_unscaled: 0.3324 (0.3292)  cardinality_error_0_unscaled: 246.2500 (245.7386)  loss_ce_enc_unscaled: 0.6250 (0.6225)  loss_bbox_enc_unscaled: 0.0295 (0.0298)  loss_giou_enc_unscaled: 0.3483 (0.3457)  cardinality_error_enc_unscaled: 252.0000 (253.1818)  time: 0.2938  data: 0.0466  max mem: 5119
# Test:  [20/24]  eta: 0:00:01  class_error: 5.76  loss: 4.2907 (4.3242)  loss_ce: 0.6172 (0.6163)  loss_bbox: 0.1246 (0.1296)  loss_giou: 0.6598 (0.6628)  loss_ce_0: 0.6406 (0.6423)  loss_bbox_0: 0.1307 (0.1357)  loss_giou_0: 0.6648 (0.6634)  loss_ce_enc: 0.6289 (0.6282)  loss_bbox_enc: 0.1488 (0.1491)  loss_giou_enc: 0.6971 (0.6969)  loss_ce_unscaled: 0.6172 (0.6163)  class_error_unscaled: 5.0360 (5.4922)  loss_bbox_unscaled: 0.0249 (0.0259)  loss_giou_unscaled: 0.3299 (0.3314)  cardinality_error_unscaled: 249.6250 (250.9762)  loss_ce_0_unscaled: 0.6406 (0.6423)  loss_bbox_0_unscaled: 0.0261 (0.0271)  loss_giou_0_unscaled: 0.3324 (0.3317)  cardinality_error_0_unscaled: 246.2500 (246.5536)  loss_ce_enc_unscaled: 0.6289 (0.6282)  loss_bbox_enc_unscaled: 0.0298 (0.0298)  loss_giou_enc_unscaled: 0.3486 (0.3485)  cardinality_error_enc_unscaled: 252.0000 (253.8274)  time: 0.2937  data: 0.0272  max mem: 5119
# Test:  [23/24]  eta: 0:00:00  class_error: 0.00  loss: 4.2905 (4.3242)  loss_ce: 0.6172 (0.6141)  loss_bbox: 0.1255 (0.1302)  loss_giou: 0.6598 (0.6649)  loss_ce_0: 0.6445 (0.6414)  loss_bbox_0: 0.1321 (0.1365)  loss_giou_0: 0.6647 (0.6648)  loss_ce_enc: 0.6289 (0.6257)  loss_bbox_enc: 0.1476 (0.1486)  loss_giou_enc: 0.6971 (0.6980)  loss_ce_unscaled: 0.6172 (0.6141)  class_error_unscaled: 5.0000 (5.2480)  loss_bbox_unscaled: 0.0251 (0.0260)  loss_giou_unscaled: 0.3299 (0.3324)  cardinality_error_unscaled: 249.5000 (250.3073)  loss_ce_0_unscaled: 0.6445 (0.6414)  loss_bbox_0_unscaled: 0.0264 (0.0273)  loss_giou_0_unscaled: 0.3324 (0.3324)  cardinality_error_0_unscaled: 244.8750 (245.8125)  loss_ce_enc_unscaled: 0.6289 (0.6257)  loss_bbox_enc_unscaled: 0.0295 (0.0297)  loss_giou_enc_unscaled: 0.3486 (0.3490)  cardinality_error_enc_unscaled: 251.7500 (253.0365)  time: 0.2860  data: 0.0269  max mem: 5119
# Test: Total time: 0:00:07 (0.2968 s / it)
# Averaged stats: class_error: 0.00  loss: 4.2905 (4.3242)  loss_ce: 0.6172 (0.6141)  loss_bbox: 0.1255 (0.1302)  loss_giou: 0.6598 (0.6649)  loss_ce_0: 0.6445 (0.6414)  loss_bbox_0: 0.1321 (0.1365)  loss_giou_0: 0.6647 (0.6648)  loss_ce_enc: 0.6289 (0.6257)  loss_bbox_enc: 0.1476 (0.1486)  loss_giou_enc: 0.6971 (0.6980)  loss_ce_unscaled: 0.6172 (0.6141)  class_error_unscaled: 5.0000 (5.2480)  loss_bbox_unscaled: 0.0251 (0.0260)  loss_giou_unscaled: 0.3299 (0.3324)  cardinality_error_unscaled: 249.5000 (250.3073)  loss_ce_0_unscaled: 0.6445 (0.6414)  loss_bbox_0_unscaled: 0.0264 (0.0273)  loss_giou_0_unscaled: 0.3324 (0.3324)  cardinality_error_0_unscaled: 244.8750 (245.8125)  loss_ce_enc_unscaled: 0.6289 (0.6257)  loss_bbox_enc_unscaled: 0.0295 (0.0297)  loss_giou_enc_unscaled: 0.3486 (0.3490)  cardinality_error_enc_unscaled: 251.7500 (253.0365)
# Accumulating evaluation results...
# DONE (t=0.32s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=500 ] = 0.271
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=500 ] = 0.519
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=500 ] = 0.263
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=500 ] = 0.127
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=500 ] = 0.583
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=500 ] = 0.321
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.129
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.356
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=500 ] = 0.380
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=500 ] = 0.334
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=500 ] = 0.686
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=500 ] = 0.510
# Grad accum steps:  2
# Total batch size:  16
# LENGTH OF DATA LOADER: 65
# Epoch: [1]  [ 0/65]  eta: 0:01:29  lr: 0.000100  class_error: 12.48  loss: 5.2178 (5.2178)  loss_ce: 0.6172 (0.6172)  loss_bbox: 0.2042 (0.2042)  loss_giou: 0.8836 (0.8836)  loss_ce_0: 0.6682 (0.6682)  loss_bbox_0: 0.2263 (0.2263)  loss_giou_0: 0.9050 (0.9050)  loss_ce_enc: 0.6048 (0.6048)  loss_bbox_enc: 0.2241 (0.2241)  loss_giou_enc: 0.8844 (0.8844)  loss_ce_unscaled: 0.6172 (0.6172)  class_error_unscaled: 12.4809 (12.4809)  loss_bbox_unscaled: 0.0408 (0.0408)  loss_giou_unscaled: 0.4418 (0.4418)  cardinality_error_unscaled: 3378.3750 (3378.3750)  loss_ce_0_unscaled: 0.6682 (0.6682)  loss_bbox_0_unscaled: 0.0453 (0.0453)  loss_giou_0_unscaled: 0.4525 (0.4525)  cardinality_error_0_unscaled: 3326.0000 (3326.0000)  loss_ce_enc_unscaled: 0.6048 (0.6048)  loss_bbox_enc_unscaled: 0.0448 (0.0448)  loss_giou_enc_unscaled: 0.4422 (0.4422)  cardinality_error_enc_unscaled: 2930.5000 (2930.5000)  time: 1.3695  data: 0.5874  max mem: 5119
# Epoch: [1]  [10/65]  eta: 0:00:47  lr: 0.000100  class_error: 4.66  loss: 4.2368 (4.4749)  loss_ce: 0.6183 (0.6238)  loss_bbox: 0.1248 (0.1451)  loss_giou: 0.6319 (0.6863)  loss_ce_0: 0.6508 (0.6572)  loss_bbox_0: 0.1335 (0.1534)  loss_giou_0: 0.6365 (0.6968)  loss_ce_enc: 0.6295 (0.6291)  loss_bbox_enc: 0.1446 (0.1628)  loss_giou_enc: 0.6795 (0.7204)  loss_ce_unscaled: 0.6183 (0.6238)  class_error_unscaled: 5.6856 (7.7744)  loss_bbox_unscaled: 0.0250 (0.0290)  loss_giou_unscaled: 0.3160 (0.3432)  cardinality_error_unscaled: 3506.5000 (3524.2614)  loss_ce_0_unscaled: 0.6508 (0.6572)  loss_bbox_0_unscaled: 0.0267 (0.0307)  loss_giou_0_unscaled: 0.3182 (0.3484)  cardinality_error_0_unscaled: 3453.3750 (3479.6705)  loss_ce_enc_unscaled: 0.6295 (0.6291)  loss_bbox_enc_unscaled: 0.0289 (0.0326)  loss_giou_enc_unscaled: 0.3397 (0.3602)  cardinality_error_enc_unscaled: 3473.5000 (3377.1023)  time: 0.8646  data: 0.0843  max mem: 5119
# Epoch: [1]  [20/65]  eta: 0:00:37  lr: 0.000100  class_error: 16.37  loss: 4.4092 (4.5318)  loss_ce: 0.6183 (0.6178)  loss_bbox: 0.1389 (0.1509)  loss_giou: 0.6787 (0.7013)  loss_ce_0: 0.6457 (0.6483)  loss_bbox_0: 0.1430 (0.1598)  loss_giou_0: 0.6912 (0.7124)  loss_ce_enc: 0.6187 (0.6223)  loss_bbox_enc: 0.1529 (0.1730)  loss_giou_enc: 0.7340 (0.7461)  loss_ce_unscaled: 0.6183 (0.6178)  class_error_unscaled: 5.0896 (6.6206)  loss_bbox_unscaled: 0.0278 (0.0302)  loss_giou_unscaled: 0.3394 (0.3506)  cardinality_error_unscaled: 3665.6250 (3608.9940)  loss_ce_0_unscaled: 0.6457 (0.6483)  loss_bbox_0_unscaled: 0.0286 (0.0320)  loss_giou_0_unscaled: 0.3456 (0.3562)  cardinality_error_0_unscaled: 3628.7500 (3573.9405)  loss_ce_enc_unscaled: 0.6187 (0.6223)  loss_bbox_enc_unscaled: 0.0306 (0.0346)  loss_giou_enc_unscaled: 0.3670 (0.3730)  cardinality_error_enc_unscaled: 3661.1250 (3477.0655)  time: 0.8090  data: 0.0357  max mem: 5119
# Epoch: [1]  [30/65]  eta: 0:00:29  lr: 0.000100  class_error: 1.51  loss: 4.4515 (4.4772)  loss_ce: 0.5878 (0.6079)  loss_bbox: 0.1389 (0.1458)  loss_giou: 0.6906 (0.6949)  loss_ce_0: 0.6151 (0.6385)  loss_bbox_0: 0.1430 (0.1543)  loss_giou_0: 0.7080 (0.7067)  loss_ce_enc: 0.6071 (0.6176)  loss_bbox_enc: 0.1613 (0.1693)  loss_giou_enc: 0.7540 (0.7422)  loss_ce_unscaled: 0.5878 (0.6079)  class_error_unscaled: 3.1810 (5.8733)  loss_bbox_unscaled: 0.0278 (0.0292)  loss_giou_unscaled: 0.3453 (0.3475)  cardinality_error_unscaled: 3698.2500 (3634.8911)  loss_ce_0_unscaled: 0.6151 (0.6385)  loss_bbox_0_unscaled: 0.0286 (0.0309)  loss_giou_0_unscaled: 0.3540 (0.3534)  cardinality_error_0_unscaled: 3663.3750 (3609.3185)  loss_ce_enc_unscaled: 0.6071 (0.6176)  loss_bbox_enc_unscaled: 0.0323 (0.0339)  loss_giou_enc_unscaled: 0.3770 (0.3711)  cardinality_error_enc_unscaled: 3711.0000 (3522.3992)  time: 0.8120  data: 0.0383  max mem: 5119
# Epoch: [1]  [40/65]  eta: 0:00:20  lr: 0.000100  class_error: 2.56  loss: 4.1336 (4.4246)  loss_ce: 0.5839 (0.6041)  loss_bbox: 0.1265 (0.1432)  loss_giou: 0.6240 (0.6857)  loss_ce_0: 0.6132 (0.6341)  loss_bbox_0: 0.1266 (0.1520)  loss_giou_0: 0.6189 (0.6964)  loss_ce_enc: 0.6022 (0.6139)  loss_bbox_enc: 0.1329 (0.1651)  loss_giou_enc: 0.6638 (0.7302)  loss_ce_unscaled: 0.5839 (0.6041)  class_error_unscaled: 4.0695 (5.7952)  loss_bbox_unscaled: 0.0253 (0.0286)  loss_giou_unscaled: 0.3120 (0.3428)  cardinality_error_unscaled: 3667.2500 (3637.9116)  loss_ce_0_unscaled: 0.6132 (0.6341)  loss_bbox_0_unscaled: 0.0253 (0.0304)  loss_giou_0_unscaled: 0.3095 (0.3482)  cardinality_error_0_unscaled: 3663.3750 (3626.0152)  loss_ce_enc_unscaled: 0.6022 (0.6139)  loss_bbox_enc_unscaled: 0.0266 (0.0330)  loss_giou_enc_unscaled: 0.3319 (0.3651)  cardinality_error_enc_unscaled: 3682.1250 (3527.7165)  time: 0.8155  data: 0.0384  max mem: 5119
# Epoch: [1]  [50/65]  eta: 0:00:12  lr: 0.000100  class_error: 0.71  loss: 4.3760 (4.4182)  loss_ce: 0.6012 (0.6031)  loss_bbox: 0.1275 (0.1425)  loss_giou: 0.6542 (0.6861)  loss_ce_0: 0.6157 (0.6333)  loss_bbox_0: 0.1335 (0.1509)  loss_giou_0: 0.6596 (0.6958)  loss_ce_enc: 0.6070 (0.6145)  loss_bbox_enc: 0.1447 (0.1639)  loss_giou_enc: 0.7265 (0.7282)  loss_ce_unscaled: 0.6012 (0.6031)  class_error_unscaled: 4.7945 (5.8813)  loss_bbox_unscaled: 0.0255 (0.0285)  loss_giou_unscaled: 0.3271 (0.3430)  cardinality_error_unscaled: 3632.2500 (3630.6838)  loss_ce_0_unscaled: 0.6157 (0.6333)  loss_bbox_0_unscaled: 0.0267 (0.0302)  loss_giou_0_unscaled: 0.3298 (0.3479)  cardinality_error_0_unscaled: 3655.8750 (3624.2819)  loss_ce_enc_unscaled: 0.6070 (0.6145)  loss_bbox_enc_unscaled: 0.0289 (0.0328)  loss_giou_enc_unscaled: 0.3632 (0.3641)  cardinality_error_enc_unscaled: 3641.7500 (3525.7230)  time: 0.8088  data: 0.0376  max mem: 5119
# Epoch: [1]  [60/65]  eta: 0:00:04  lr: 0.000100  class_error: 4.32  loss: 4.3489 (4.3916)  loss_ce: 0.5924 (0.5991)  loss_bbox: 0.1262 (0.1410)  loss_giou: 0.6754 (0.6822)  loss_ce_0: 0.6127 (0.6294)  loss_bbox_0: 0.1335 (0.1494)  loss_giou_0: 0.6977 (0.6934)  loss_ce_enc: 0.6035 (0.6117)  loss_bbox_enc: 0.1469 (0.1617)  loss_giou_enc: 0.7305 (0.7237)  loss_ce_unscaled: 0.5924 (0.5991)  class_error_unscaled: 4.3203 (5.7023)  loss_bbox_unscaled: 0.0252 (0.0282)  loss_giou_unscaled: 0.3377 (0.3411)  cardinality_error_unscaled: 3632.2500 (3629.9344)  loss_ce_0_unscaled: 0.6127 (0.6294)  loss_bbox_0_unscaled: 0.0267 (0.0299)  loss_giou_0_unscaled: 0.3488 (0.3467)  cardinality_error_0_unscaled: 3621.5000 (3624.2070)  loss_ce_enc_unscaled: 0.6035 (0.6117)  loss_bbox_enc_unscaled: 0.0294 (0.0323)  loss_giou_enc_unscaled: 0.3653 (0.3618)  cardinality_error_enc_unscaled: 3627.1250 (3515.3094)  time: 0.8196  data: 0.0376  max mem: 5119
# Epoch: [1]  [64/65]  eta: 0:00:00  lr: 0.000100  class_error: 1.59  loss: 4.2916 (4.3912)  loss_ce: 0.5796 (0.5987)  loss_bbox: 0.1264 (0.1416)  loss_giou: 0.6611 (0.6821)  loss_ce_0: 0.6115 (0.6289)  loss_bbox_0: 0.1297 (0.1504)  loss_giou_0: 0.6757 (0.6942)  loss_ce_enc: 0.6001 (0.6102)  loss_bbox_enc: 0.1469 (0.1619)  loss_giou_enc: 0.7286 (0.7233)  loss_ce_unscaled: 0.5796 (0.5987)  class_error_unscaled: 3.2680 (5.8013)  loss_bbox_unscaled: 0.0253 (0.0283)  loss_giou_unscaled: 0.3306 (0.3410)  cardinality_error_unscaled: 3636.0000 (3631.9000)  loss_ce_0_unscaled: 0.6115 (0.6289)  loss_bbox_0_unscaled: 0.0259 (0.0301)  loss_giou_0_unscaled: 0.3378 (0.3471)  cardinality_error_0_unscaled: 3632.0000 (3626.8500)  loss_ce_enc_unscaled: 0.6001 (0.6102)  loss_bbox_enc_unscaled: 0.0294 (0.0324)  loss_giou_enc_unscaled: 0.3643 (0.3617)  cardinality_error_enc_unscaled: 3629.0000 (3504.5846)  time: 0.8242  data: 0.0376  max mem: 5119
# Epoch: [1] Total time: 0:00:53 (0.8233 s / it)
# Averaged stats: lr: 0.000100  class_error: 1.59  loss: 4.2916 (4.3912)  loss_ce: 0.5796 (0.5987)  loss_bbox: 0.1264 (0.1416)  loss_giou: 0.6611 (0.6821)  loss_ce_0: 0.6115 (0.6289)  loss_bbox_0: 0.1297 (0.1504)  loss_giou_0: 0.6757 (0.6942)  loss_ce_enc: 0.6001 (0.6102)  loss_bbox_enc: 0.1469 (0.1619)  loss_giou_enc: 0.7286 (0.7233)  loss_ce_unscaled: 0.5796 (0.5987)  class_error_unscaled: 3.2680 (5.8013)  loss_bbox_unscaled: 0.0253 (0.0283)  loss_giou_unscaled: 0.3306 (0.3410)  cardinality_error_unscaled: 3636.0000 (3631.9000)  loss_ce_0_unscaled: 0.6115 (0.6289)  loss_bbox_0_unscaled: 0.0259 (0.0301)  loss_giou_0_unscaled: 0.3378 (0.3471)  cardinality_error_0_unscaled: 3632.0000 (3626.8500)  loss_ce_enc_unscaled: 0.6001 (0.6102)  loss_bbox_enc_unscaled: 0.0294 (0.0324)  loss_giou_enc_unscaled: 0.3643 (0.3617)  cardinality_error_enc_unscaled: 3629.0000 (3504.5846)
# Test:  [ 0/24]  eta: 0:00:12  class_error: 5.81  loss: 4.1225 (4.1225)  loss_ce: 0.5664 (0.5664)  loss_bbox: 0.1044 (0.1044)  loss_giou: 0.6455 (0.6455)  loss_ce_0: 0.5898 (0.5898)  loss_bbox_0: 0.1136 (0.1136)  loss_giou_0: 0.6573 (0.6573)  loss_ce_enc: 0.5938 (0.5938)  loss_bbox_enc: 0.1394 (0.1394)  loss_giou_enc: 0.7124 (0.7124)  loss_ce_unscaled: 0.5664 (0.5664)  class_error_unscaled: 5.8065 (5.8065)  loss_bbox_unscaled: 0.0209 (0.0209)  loss_giou_unscaled: 0.3227 (0.3227)  cardinality_error_unscaled: 264.3750 (264.3750)  loss_ce_0_unscaled: 0.5898 (0.5898)  loss_bbox_0_unscaled: 0.0227 (0.0227)  loss_giou_0_unscaled: 0.3286 (0.3286)  cardinality_error_0_unscaled: 264.3750 (264.3750)  loss_ce_enc_unscaled: 0.5938 (0.5938)  loss_bbox_enc_unscaled: 0.0279 (0.0279)  loss_giou_enc_unscaled: 0.3562 (0.3562)  cardinality_error_enc_unscaled: 264.6250 (264.6250)  time: 0.5341  data: 0.2489  max mem: 5119
# Test:  [10/24]  eta: 0:00:04  class_error: 4.67  loss: 4.1475 (4.1251)  loss_ce: 0.5781 (0.5771)  loss_bbox: 0.1149 (0.1218)  loss_giou: 0.6293 (0.6243)  loss_ce_0: 0.5977 (0.6005)  loss_bbox_0: 0.1264 (0.1325)  loss_giou_0: 0.6328 (0.6270)  loss_ce_enc: 0.5938 (0.5962)  loss_bbox_enc: 0.1570 (0.1577)  loss_giou_enc: 0.6932 (0.6881)  loss_ce_unscaled: 0.5781 (0.5771)  class_error_unscaled: 2.8777 (2.9838)  loss_bbox_unscaled: 0.0230 (0.0244)  loss_giou_unscaled: 0.3146 (0.3121)  cardinality_error_unscaled: 267.2500 (268.1364)  loss_ce_0_unscaled: 0.5977 (0.6005)  loss_bbox_0_unscaled: 0.0253 (0.0265)  loss_giou_0_unscaled: 0.3164 (0.3135)  cardinality_error_0_unscaled: 267.6250 (267.7159)  loss_ce_enc_unscaled: 0.5938 (0.5962)  loss_bbox_enc_unscaled: 0.0314 (0.0315)  loss_giou_enc_unscaled: 0.3466 (0.3440)  cardinality_error_enc_unscaled: 266.6250 (266.6932)  time: 0.3276  data: 0.0429  max mem: 5119
# Test:  [20/24]  eta: 0:00:01  class_error: 2.88  loss: 4.1475 (4.1511)  loss_ce: 0.5781 (0.5792)  loss_bbox: 0.1171 (0.1195)  loss_giou: 0.6271 (0.6316)  loss_ce_0: 0.5977 (0.6016)  loss_bbox_0: 0.1259 (0.1284)  loss_giou_0: 0.6356 (0.6380)  loss_ce_enc: 0.5977 (0.6016)  loss_bbox_enc: 0.1551 (0.1549)  loss_giou_enc: 0.6924 (0.6963)  loss_ce_unscaled: 0.5781 (0.5792)  class_error_unscaled: 2.9412 (3.2834)  loss_bbox_unscaled: 0.0234 (0.0239)  loss_giou_unscaled: 0.3136 (0.3158)  cardinality_error_unscaled: 267.5000 (268.2262)  loss_ce_0_unscaled: 0.5977 (0.6016)  loss_bbox_0_unscaled: 0.0252 (0.0257)  loss_giou_0_unscaled: 0.3178 (0.3190)  cardinality_error_0_unscaled: 267.6250 (268.0595)  loss_ce_enc_unscaled: 0.5977 (0.6016)  loss_bbox_enc_unscaled: 0.0310 (0.0310)  loss_giou_enc_unscaled: 0.3462 (0.3482)  cardinality_error_enc_unscaled: 265.1250 (266.6726)  time: 0.2773  data: 0.0224  max mem: 5119
# Test:  [23/24]  eta: 0:00:00  class_error: 0.00  loss: 4.1475 (4.1516)  loss_ce: 0.5781 (0.5780)  loss_bbox: 0.1171 (0.1195)  loss_giou: 0.6271 (0.6339)  loss_ce_0: 0.5977 (0.6012)  loss_bbox_0: 0.1257 (0.1280)  loss_giou_0: 0.6392 (0.6400)  loss_ce_enc: 0.6016 (0.6004)  loss_bbox_enc: 0.1518 (0.1540)  loss_giou_enc: 0.6924 (0.6967)  loss_ce_unscaled: 0.5781 (0.5780)  class_error_unscaled: 2.8777 (3.1365)  loss_bbox_unscaled: 0.0234 (0.0239)  loss_giou_unscaled: 0.3136 (0.3169)  cardinality_error_unscaled: 267.2500 (268.2031)  loss_ce_0_unscaled: 0.5977 (0.6012)  loss_bbox_0_unscaled: 0.0251 (0.0256)  loss_giou_0_unscaled: 0.3196 (0.3200)  cardinality_error_0_unscaled: 267.3750 (267.9010)  loss_ce_enc_unscaled: 0.6016 (0.6004)  loss_bbox_enc_unscaled: 0.0304 (0.0308)  loss_giou_enc_unscaled: 0.3462 (0.3483)  cardinality_error_enc_unscaled: 265.1250 (266.3490)  time: 0.2691  data: 0.0217  max mem: 5119
# Test: Total time: 0:00:06 (0.2814 s / it)
# Averaged stats: class_error: 0.00  loss: 4.1475 (4.1516)  loss_ce: 0.5781 (0.5780)  loss_bbox: 0.1171 (0.1195)  loss_giou: 0.6271 (0.6339)  loss_ce_0: 0.5977 (0.6012)  loss_bbox_0: 0.1257 (0.1280)  loss_giou_0: 0.6392 (0.6400)  loss_ce_enc: 0.6016 (0.6004)  loss_bbox_enc: 0.1518 (0.1540)  loss_giou_enc: 0.6924 (0.6967)  loss_ce_unscaled: 0.5781 (0.5780)  class_error_unscaled: 2.8777 (3.1365)  loss_bbox_unscaled: 0.0234 (0.0239)  loss_giou_unscaled: 0.3136 (0.3169)  cardinality_error_unscaled: 267.2500 (268.2031)  loss_ce_0_unscaled: 0.5977 (0.6012)  loss_bbox_0_unscaled: 0.0251 (0.0256)  loss_giou_0_unscaled: 0.3196 (0.3200)  cardinality_error_0_unscaled: 267.3750 (267.9010)  loss_ce_enc_unscaled: 0.6016 (0.6004)  loss_bbox_enc_unscaled: 0.0304 (0.0308)  loss_giou_enc_unscaled: 0.3462 (0.3483)  cardinality_error_enc_unscaled: 265.1250 (266.3490)
# Accumulating evaluation results...
# DONE (t=0.31s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=500 ] = 0.325
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=500 ] = 0.618
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=500 ] = 0.305
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=500 ] = 0.196
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=500 ] = 0.623
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=500 ] = 0.341
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.171
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.409
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=500 ] = 0.425
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=500 ] = 0.329
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=500 ] = 0.709
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=500 ] = 0.534
# Test:  [ 0/24]  eta: 0:00:13  class_error: 4.52  loss: 4.0270 (4.0270)  loss_ce: 0.5625 (0.5625)  loss_bbox: 0.1040 (0.1040)  loss_giou: 0.6453 (0.6453)  loss_ce_0: 0.5820 (0.5820)  loss_bbox_0: 0.1101 (0.1101)  loss_giou_0: 0.6514 (0.6514)  loss_ce_enc: 0.5781 (0.5781)  loss_bbox_enc: 0.1174 (0.1174)  loss_giou_enc: 0.6762 (0.6762)  loss_ce_unscaled: 0.5625 (0.5625)  class_error_unscaled: 4.5161 (4.5161)  loss_bbox_unscaled: 0.0208 (0.0208)  loss_giou_unscaled: 0.3226 (0.3226)  cardinality_error_unscaled: 262.7500 (262.7500)  loss_ce_0_unscaled: 0.5820 (0.5820)  loss_bbox_0_unscaled: 0.0220 (0.0220)  loss_giou_0_unscaled: 0.3257 (0.3257)  cardinality_error_0_unscaled: 263.2500 (263.2500)  loss_ce_enc_unscaled: 0.5781 (0.5781)  loss_bbox_enc_unscaled: 0.0235 (0.0235)  loss_giou_enc_unscaled: 0.3381 (0.3381)  cardinality_error_enc_unscaled: 264.0000 (264.0000)  time: 0.5603  data: 0.2613  max mem: 5119
# Test:  [10/24]  eta: 0:00:04  class_error: 4.67  loss: 4.0605 (4.0527)  loss_ce: 0.5703 (0.5728)  loss_bbox: 0.1163 (0.1225)  loss_giou: 0.6396 (0.6272)  loss_ce_0: 0.5898 (0.5948)  loss_bbox_0: 0.1249 (0.1294)  loss_giou_0: 0.6327 (0.6245)  loss_ce_enc: 0.5781 (0.5831)  loss_bbox_enc: 0.1391 (0.1396)  loss_giou_enc: 0.6683 (0.6588)  loss_ce_unscaled: 0.5703 (0.5728)  class_error_unscaled: 2.5424 (2.8720)  loss_bbox_unscaled: 0.0233 (0.0245)  loss_giou_unscaled: 0.3198 (0.3136)  cardinality_error_unscaled: 266.5000 (266.8864)  loss_ce_0_unscaled: 0.5898 (0.5948)  loss_bbox_0_unscaled: 0.0250 (0.0259)  loss_giou_0_unscaled: 0.3164 (0.3122)  cardinality_error_0_unscaled: 266.2500 (266.4659)  loss_ce_enc_unscaled: 0.5781 (0.5831)  loss_bbox_enc_unscaled: 0.0278 (0.0279)  loss_giou_enc_unscaled: 0.3341 (0.3294)  cardinality_error_enc_unscaled: 265.5000 (265.5568)  time: 0.3396  data: 0.0471  max mem: 5119
# Test:  [20/24]  eta: 0:00:01  class_error: 2.16  loss: 4.0631 (4.0751)  loss_ce: 0.5703 (0.5766)  loss_bbox: 0.1163 (0.1191)  loss_giou: 0.6246 (0.6302)  loss_ce_0: 0.5977 (0.5993)  loss_bbox_0: 0.1244 (0.1255)  loss_giou_0: 0.6317 (0.6323)  loss_ce_enc: 0.5820 (0.5889)  loss_bbox_enc: 0.1359 (0.1366)  loss_giou_enc: 0.6636 (0.6665)  loss_ce_unscaled: 0.5703 (0.5766)  class_error_unscaled: 2.5424 (3.0872)  loss_bbox_unscaled: 0.0233 (0.0238)  loss_giou_unscaled: 0.3123 (0.3151)  cardinality_error_unscaled: 266.5000 (266.9702)  loss_ce_0_unscaled: 0.5977 (0.5993)  loss_bbox_0_unscaled: 0.0249 (0.0251)  loss_giou_0_unscaled: 0.3159 (0.3162)  cardinality_error_0_unscaled: 266.2500 (266.8690)  loss_ce_enc_unscaled: 0.5820 (0.5889)  loss_bbox_enc_unscaled: 0.0272 (0.0273)  loss_giou_enc_unscaled: 0.3318 (0.3333)  cardinality_error_enc_unscaled: 264.6250 (265.7083)  time: 0.2895  data: 0.0242  max mem: 5119
# Test:  [23/24]  eta: 0:00:00  class_error: 0.00  loss: 4.0605 (4.0756)  loss_ce: 0.5703 (0.5752)  loss_bbox: 0.1163 (0.1193)  loss_giou: 0.6275 (0.6326)  loss_ce_0: 0.5977 (0.5988)  loss_bbox_0: 0.1221 (0.1253)  loss_giou_0: 0.6317 (0.6335)  loss_ce_enc: 0.5898 (0.5876)  loss_bbox_enc: 0.1345 (0.1361)  loss_giou_enc: 0.6651 (0.6672)  loss_ce_unscaled: 0.5703 (0.5752)  class_error_unscaled: 2.5424 (2.9348)  loss_bbox_unscaled: 0.0233 (0.0239)  loss_giou_unscaled: 0.3138 (0.3163)  cardinality_error_unscaled: 265.8750 (266.8854)  loss_ce_0_unscaled: 0.5977 (0.5988)  loss_bbox_0_unscaled: 0.0244 (0.0251)  loss_giou_0_unscaled: 0.3159 (0.3168)  cardinality_error_0_unscaled: 266.1250 (266.7604)  loss_ce_enc_unscaled: 0.5898 (0.5876)  loss_bbox_enc_unscaled: 0.0269 (0.0272)  loss_giou_enc_unscaled: 0.3325 (0.3336)  cardinality_error_enc_unscaled: 264.1250 (265.3125)  time: 0.2805  data: 0.0228  max mem: 5119
# Test: Total time: 0:00:07 (0.2934 s / it)
# Averaged stats: class_error: 0.00  loss: 4.0605 (4.0756)  loss_ce: 0.5703 (0.5752)  loss_bbox: 0.1163 (0.1193)  loss_giou: 0.6275 (0.6326)  loss_ce_0: 0.5977 (0.5988)  loss_bbox_0: 0.1221 (0.1253)  loss_giou_0: 0.6317 (0.6335)  loss_ce_enc: 0.5898 (0.5876)  loss_bbox_enc: 0.1345 (0.1361)  loss_giou_enc: 0.6651 (0.6672)  loss_ce_unscaled: 0.5703 (0.5752)  class_error_unscaled: 2.5424 (2.9348)  loss_bbox_unscaled: 0.0233 (0.0239)  loss_giou_unscaled: 0.3138 (0.3163)  cardinality_error_unscaled: 265.8750 (266.8854)  loss_ce_0_unscaled: 0.5977 (0.5988)  loss_bbox_0_unscaled: 0.0244 (0.0251)  loss_giou_0_unscaled: 0.3159 (0.3168)  cardinality_error_0_unscaled: 266.1250 (266.7604)  loss_ce_enc_unscaled: 0.5898 (0.5876)  loss_bbox_enc_unscaled: 0.0269 (0.0272)  loss_giou_enc_unscaled: 0.3325 (0.3336)  cardinality_error_enc_unscaled: 264.1250 (265.3125)
# Accumulating evaluation results...
# DONE (t=0.32s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=500 ] = 0.328
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=500 ] = 0.631
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=500 ] = 0.307
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=500 ] = 0.204
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=500 ] = 0.620
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=500 ] = 0.329
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.176
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.413
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=500 ] = 0.428
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=500 ] = 0.384
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=500 ] = 0.705
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=500 ] = 0.531
# Grad accum steps:  2
# Total batch size:  16
# LENGTH OF DATA LOADER: 65
# Epoch: [2]  [ 0/65]  eta: 0:01:38  lr: 0.000100  class_error: 3.55  loss: 4.0741 (4.0741)  loss_ce: 0.5636 (0.5636)  loss_bbox: 0.1298 (0.1298)  loss_giou: 0.6153 (0.6153)  loss_ce_0: 0.5908 (0.5908)  loss_bbox_0: 0.1401 (0.1401)  loss_giou_0: 0.6218 (0.6218)  loss_ce_enc: 0.5761 (0.5761)  loss_bbox_enc: 0.1543 (0.1543)  loss_giou_enc: 0.6823 (0.6823)  loss_ce_unscaled: 0.5636 (0.5636)  class_error_unscaled: 3.5544 (3.5544)  loss_bbox_unscaled: 0.0260 (0.0260)  loss_giou_unscaled: 0.3077 (0.3077)  cardinality_error_unscaled: 3619.7500 (3619.7500)  loss_ce_0_unscaled: 0.5908 (0.5908)  loss_bbox_0_unscaled: 0.0280 (0.0280)  loss_giou_0_unscaled: 0.3109 (0.3109)  cardinality_error_0_unscaled: 3623.5000 (3623.5000)  loss_ce_enc_unscaled: 0.5761 (0.5761)  loss_bbox_enc_unscaled: 0.0309 (0.0309)  loss_giou_enc_unscaled: 0.3412 (0.3412)  cardinality_error_enc_unscaled: 3644.7500 (3644.7500)  time: 1.5126  data: 0.6358  max mem: 5119
# Epoch: [2]  [10/65]  eta: 0:00:49  lr: 0.000100  class_error: 3.22  loss: 3.8547 (4.2319)  loss_ce: 0.5676 (0.5782)  loss_bbox: 0.1081 (0.1362)  loss_giou: 0.5830 (0.6569)  loss_ce_0: 0.6035 (0.6122)  loss_bbox_0: 0.1102 (0.1464)  loss_giou_0: 0.5831 (0.6648)  loss_ce_enc: 0.5975 (0.5917)  loss_bbox_enc: 0.1314 (0.1564)  loss_giou_enc: 0.6282 (0.6891)  loss_ce_unscaled: 0.5676 (0.5782)  class_error_unscaled: 3.2651 (4.3296)  loss_bbox_unscaled: 0.0216 (0.0272)  loss_giou_unscaled: 0.2915 (0.3285)  cardinality_error_unscaled: 3682.5000 (3677.3977)  loss_ce_0_unscaled: 0.6035 (0.6122)  loss_bbox_0_unscaled: 0.0220 (0.0293)  loss_giou_0_unscaled: 0.2915 (0.3324)  cardinality_error_0_unscaled: 3690.8750 (3686.7273)  loss_ce_enc_unscaled: 0.5975 (0.5917)  loss_bbox_enc_unscaled: 0.0263 (0.0313)  loss_giou_enc_unscaled: 0.3141 (0.3445)  cardinality_error_enc_unscaled: 3660.5000 (3460.9091)  time: 0.8944  data: 0.0886  max mem: 5178
# Epoch: [2]  [20/65]  eta: 0:00:38  lr: 0.000100  class_error: 2.83  loss: 3.8200 (4.1232)  loss_ce: 0.5628 (0.5709)  loss_bbox: 0.1081 (0.1289)  loss_giou: 0.5720 (0.6404)  loss_ce_0: 0.5854 (0.6023)  loss_bbox_0: 0.1102 (0.1359)  loss_giou_0: 0.5737 (0.6455)  loss_ce_enc: 0.5826 (0.5847)  loss_bbox_enc: 0.1259 (0.1440)  loss_giou_enc: 0.6113 (0.6707)  loss_ce_unscaled: 0.5628 (0.5709)  class_error_unscaled: 2.8257 (4.0129)  loss_bbox_unscaled: 0.0216 (0.0258)  loss_giou_unscaled: 0.2860 (0.3202)  cardinality_error_unscaled: 3688.0000 (3681.8750)  loss_ce_0_unscaled: 0.5854 (0.6023)  loss_bbox_0_unscaled: 0.0220 (0.0272)  loss_giou_0_unscaled: 0.2869 (0.3228)  cardinality_error_0_unscaled: 3690.8750 (3692.0833)  loss_ce_enc_unscaled: 0.5826 (0.5847)  loss_bbox_enc_unscaled: 0.0252 (0.0288)  loss_giou_enc_unscaled: 0.3056 (0.3353)  cardinality_error_enc_unscaled: 3672.3750 (3554.9643)  time: 0.8246  data: 0.0367  max mem: 5178
# Epoch: [2]  [30/65]  eta: 0:00:29  lr: 0.000100  class_error: 12.37  loss: 3.7359 (4.1080)  loss_ce: 0.5591 (0.5714)  loss_bbox: 0.1092 (0.1285)  loss_giou: 0.5683 (0.6363)  loss_ce_0: 0.5853 (0.6025)  loss_bbox_0: 0.1079 (0.1349)  loss_giou_0: 0.5646 (0.6421)  loss_ce_enc: 0.5744 (0.5854)  loss_bbox_enc: 0.1211 (0.1424)  loss_giou_enc: 0.5971 (0.6645)  loss_ce_unscaled: 0.5591 (0.5714)  class_error_unscaled: 2.0067 (3.8352)  loss_bbox_unscaled: 0.0218 (0.0257)  loss_giou_unscaled: 0.2841 (0.3182)  cardinality_error_unscaled: 3691.5000 (3682.6411)  loss_ce_0_unscaled: 0.5853 (0.6025)  loss_bbox_0_unscaled: 0.0216 (0.0270)  loss_giou_0_unscaled: 0.2823 (0.3211)  cardinality_error_0_unscaled: 3690.7500 (3692.3548)  loss_ce_enc_unscaled: 0.5744 (0.5854)  loss_bbox_enc_unscaled: 0.0242 (0.0285)  loss_giou_enc_unscaled: 0.2986 (0.3322)  cardinality_error_enc_unscaled: 3696.5000 (3548.4879)  time: 0.8297  data: 0.0387  max mem: 5178
# ...
# Test: Total time: 0:00:06 (0.2837 s / it)
# Averaged stats: class_error: 0.00  loss: 3.6384 (3.6473)  loss_ce: 0.5469 (0.5469)  loss_bbox: 0.0989 (0.1023)  loss_giou: 0.5247 (0.5401)  loss_ce_0: 0.5625 (0.5622)  loss_bbox_0: 0.1038 (0.1058)  loss_giou_0: 0.5447 (0.5467)  loss_ce_enc: 0.5625 (0.5654)  loss_bbox_enc: 0.1116 (0.1129)  loss_giou_enc: 0.5507 (0.5650)  loss_ce_unscaled: 0.5469 (0.5469)  class_error_unscaled: 1.3245 (1.2099)  loss_bbox_unscaled: 0.0198 (0.0205)  loss_giou_unscaled: 0.2624 (0.2701)  cardinality_error_unscaled: 280.2500 (280.7240)  loss_ce_0_unscaled: 0.5625 (0.5622)  loss_bbox_0_unscaled: 0.0208 (0.0212)  loss_giou_0_unscaled: 0.2724 (0.2734)  cardinality_error_0_unscaled: 279.2500 (279.8750)  loss_ce_enc_unscaled: 0.5625 (0.5654)  loss_bbox_enc_unscaled: 0.0223 (0.0226)  loss_giou_enc_unscaled: 0.2753 (0.2825)  cardinality_error_enc_unscaled: 278.8750 (279.2396)
# Accumulating evaluation results...
# DONE (t=0.33s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=500 ] = 0.430
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=500 ] = 0.758
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=500 ] = 0.427
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=500 ] = 0.332
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=500 ] = 0.661
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=500 ] = 0.372
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.255
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.495
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=500 ] = 0.511
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=500 ] = 0.404
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=500 ] = 0.723
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=500 ] = 0.595
# Test:  [ 0/24]  eta: 0:00:14  class_error: 1.29  loss: 3.6272 (3.6272)  loss_ce: 0.5234 (0.5234)  loss_bbox: 0.0901 (0.0901)  loss_giou: 0.5553 (0.5553)  loss_ce_0: 0.5469 (0.5469)  loss_bbox_0: 0.0966 (0.0966)  loss_giou_0: 0.5648 (0.5648)  loss_ce_enc: 0.5625 (0.5625)  loss_bbox_enc: 0.1006 (0.1006)  loss_giou_enc: 0.5869 (0.5869)  loss_ce_unscaled: 0.5234 (0.5234)  class_error_unscaled: 1.2903 (1.2903)  loss_bbox_unscaled: 0.0180 (0.0180)  loss_giou_unscaled: 0.2777 (0.2777)  cardinality_error_unscaled: 278.3750 (278.3750)  loss_ce_0_unscaled: 0.5469 (0.5469)  loss_bbox_0_unscaled: 0.0193 (0.0193)  loss_giou_0_unscaled: 0.2824 (0.2824)  cardinality_error_0_unscaled: 275.8750 (275.8750)  loss_ce_enc_unscaled: 0.5625 (0.5625)  loss_bbox_enc_unscaled: 0.0201 (0.0201)  loss_giou_enc_unscaled: 0.2934 (0.2934)  cardinality_error_enc_unscaled: 276.8750 (276.8750)  time: 0.6051  data: 0.2768  max mem: 5216
# Test:  [10/24]  eta: 0:00:04  class_error: 1.87  loss: 3.6218 (3.6314)  loss_ce: 0.5391 (0.5366)  loss_bbox: 0.1035 (0.1064)  loss_giou: 0.5481 (0.5409)  loss_ce_0: 0.5547 (0.5565)  loss_bbox_0: 0.1077 (0.1094)  loss_giou_0: 0.5534 (0.5444)  loss_ce_enc: 0.5586 (0.5600)  loss_bbox_enc: 0.1135 (0.1146)  loss_giou_enc: 0.5734 (0.5626)  loss_ce_unscaled: 0.5391 (0.5366)  class_error_unscaled: 0.8475 (0.9514)  loss_bbox_unscaled: 0.0207 (0.0213)  loss_giou_unscaled: 0.2740 (0.2705)  cardinality_error_unscaled: 279.3750 (279.8750)  loss_ce_0_unscaled: 0.5547 (0.5565)  loss_bbox_0_unscaled: 0.0215 (0.0219)  loss_giou_0_unscaled: 0.2767 (0.2722)  cardinality_error_0_unscaled: 278.3750 (278.3864)  loss_ce_enc_unscaled: 0.5586 (0.5600)  loss_bbox_enc_unscaled: 0.0227 (0.0229)  loss_giou_enc_unscaled: 0.2867 (0.2813)  cardinality_error_enc_unscaled: 279.2500 (278.9886)  time: 0.2956  data: 0.0470  max mem: 5216
# Test:  [20/24]  eta: 0:00:01  class_error: 1.44  loss: 3.6087 (3.6254)  loss_ce: 0.5430 (0.5392)  loss_bbox: 0.1001 (0.1023)  loss_giou: 0.5365 (0.5401)  loss_ce_0: 0.5625 (0.5586)  loss_bbox_0: 0.1030 (0.1050)  loss_giou_0: 0.5343 (0.5445)  loss_ce_enc: 0.5586 (0.5627)  loss_bbox_enc: 0.1080 (0.1103)  loss_giou_enc: 0.5599 (0.5629)  loss_ce_unscaled: 0.5430 (0.5392)  class_error_unscaled: 1.4084 (1.1446)  loss_bbox_unscaled: 0.0200 (0.0205)  loss_giou_unscaled: 0.2682 (0.2701)  cardinality_error_unscaled: 279.5000 (280.1667)  loss_ce_0_unscaled: 0.5625 (0.5586)  loss_bbox_0_unscaled: 0.0206 (0.0210)  loss_giou_0_unscaled: 0.2672 (0.2722)  cardinality_error_0_unscaled: 277.8750 (278.6131)  loss_ce_enc_unscaled: 0.5586 (0.5627)  loss_bbox_enc_unscaled: 0.0216 (0.0221)  loss_giou_enc_unscaled: 0.2800 (0.2814)  cardinality_error_enc_unscaled: 279.1250 (279.2798)  time: 0.2887  data: 0.0233  max mem: 5216
# Test:  [23/24]  eta: 0:00:00  class_error: 0.00  loss: 3.6031 (3.6163)  loss_ce: 0.5391 (0.5389)  loss_bbox: 0.0980 (0.1020)  loss_giou: 0.5286 (0.5385)  loss_ce_0: 0.5586 (0.5591)  loss_bbox_0: 0.1028 (0.1045)  loss_giou_0: 0.5310 (0.5423)  loss_ce_enc: 0.5586 (0.5617)  loss_bbox_enc: 0.1078 (0.1097)  loss_giou_enc: 0.5566 (0.5596)  loss_ce_unscaled: 0.5391 (0.5389)  class_error_unscaled: 0.9091 (1.0914)  loss_bbox_unscaled: 0.0196 (0.0204)  loss_giou_unscaled: 0.2643 (0.2693)  cardinality_error_unscaled: 279.5000 (279.9688)  loss_ce_0_unscaled: 0.5586 (0.5591)  loss_bbox_0_unscaled: 0.0206 (0.0209)  loss_giou_0_unscaled: 0.2655 (0.2712)  cardinality_error_0_unscaled: 277.8750 (278.5260)  loss_ce_enc_unscaled: 0.5586 (0.5617)  loss_bbox_enc_unscaled: 0.0216 (0.0219)  loss_giou_enc_unscaled: 0.2783 (0.2798)  cardinality_error_enc_unscaled: 278.7500 (279.0938)  time: 0.2797  data: 0.0225  max mem: 5216
# Test: Total time: 0:00:07 (0.2956 s / it)
# Averaged stats: class_error: 0.00  loss: 3.6031 (3.6163)  loss_ce: 0.5391 (0.5389)  loss_bbox: 0.0980 (0.1020)  loss_giou: 0.5286 (0.5385)  loss_ce_0: 0.5586 (0.5591)  loss_bbox_0: 0.1028 (0.1045)  loss_giou_0: 0.5310 (0.5423)  loss_ce_enc: 0.5586 (0.5617)  loss_bbox_enc: 0.1078 (0.1097)  loss_giou_enc: 0.5566 (0.5596)  loss_ce_unscaled: 0.5391 (0.5389)  class_error_unscaled: 0.9091 (1.0914)  loss_bbox_unscaled: 0.0196 (0.0204)  loss_giou_unscaled: 0.2643 (0.2693)  cardinality_error_unscaled: 279.5000 (279.9688)  loss_ce_0_unscaled: 0.5586 (0.5591)  loss_bbox_0_unscaled: 0.0206 (0.0209)  loss_giou_0_unscaled: 0.2655 (0.2712)  cardinality_error_0_unscaled: 277.8750 (278.5260)  loss_ce_enc_unscaled: 0.5586 (0.5617)  loss_bbox_enc_unscaled: 0.0216 (0.0219)  loss_giou_enc_unscaled: 0.2783 (0.2798)  cardinality_error_enc_unscaled: 278.7500 (279.0938)
# Accumulating evaluation results...
# DONE (t=0.34s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=500 ] = 0.435
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=500 ] = 0.762
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=500 ] = 0.424
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=500 ] = 0.334
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=500 ] = 0.673
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=500 ] = 0.350
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.255
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.496
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=500 ] = 0.514
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=500 ] = 0.402
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=500 ] = 0.734
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=500 ] = 0.598
# Training time 0:11:58
# Results saved to output/results.json
# Test:  [ 0/22]  eta: 0:00:12  class_error: 0.00  loss: 3.4014 (3.4014)  loss_ce: 0.5078 (0.5078)  loss_bbox: 0.0877 (0.0877)  loss_giou: 0.5070 (0.5070)  loss_ce_0: 0.5234 (0.5234)  loss_bbox_0: 0.0909 (0.0909)  loss_giou_0: 0.5145 (0.5145)  loss_ce_enc: 0.5430 (0.5430)  loss_bbox_enc: 0.1006 (0.1006)  loss_giou_enc: 0.5265 (0.5265)  loss_ce_unscaled: 0.5078 (0.5078)  class_error_unscaled: 0.0000 (0.0000)  loss_bbox_unscaled: 0.0175 (0.0175)  loss_giou_unscaled: 0.2535 (0.2535)  cardinality_error_unscaled: 279.8750 (279.8750)  loss_ce_0_unscaled: 0.5234 (0.5234)  loss_bbox_0_unscaled: 0.0182 (0.0182)  loss_giou_0_unscaled: 0.2572 (0.2572)  cardinality_error_0_unscaled: 278.6250 (278.6250)  loss_ce_enc_unscaled: 0.5430 (0.5430)  loss_bbox_enc_unscaled: 0.0201 (0.0201)  loss_giou_enc_unscaled: 0.2632 (0.2632)  cardinality_error_enc_unscaled: 278.8750 (278.8750)  time: 0.5854  data: 0.2787  max mem: 5216
# Test:  [10/22]  eta: 0:00:03  class_error: 2.27  loss: 3.4979 (3.4712)  loss_ce: 0.5195 (0.5259)  loss_bbox: 0.0884 (0.0908)  loss_giou: 0.5263 (0.5127)  loss_ce_0: 0.5352 (0.5412)  loss_bbox_0: 0.0909 (0.0925)  loss_giou_0: 0.5199 (0.5196)  loss_ce_enc: 0.5469 (0.5511)  loss_bbox_enc: 0.1006 (0.1007)  loss_giou_enc: 0.5478 (0.5367)  loss_ce_unscaled: 0.5195 (0.5259)  class_error_unscaled: 0.7407 (0.8926)  loss_bbox_unscaled: 0.0177 (0.0182)  loss_giou_unscaled: 0.2632 (0.2564)  cardinality_error_unscaled: 278.6250 (278.6705)  loss_ce_0_unscaled: 0.5352 (0.5412)  loss_bbox_0_unscaled: 0.0182 (0.0185)  loss_giou_0_unscaled: 0.2600 (0.2598)  cardinality_error_0_unscaled: 278.0000 (277.3977)  loss_ce_enc_unscaled: 0.5469 (0.5511)  loss_bbox_enc_unscaled: 0.0201 (0.0201)  loss_giou_enc_unscaled: 0.2739 (0.2684)  cardinality_error_enc_unscaled: 278.1250 (277.7159)  time: 0.3114  data: 0.0467  max mem: 5216
# Test:  [20/22]  eta: 0:00:00  class_error: 0.63  loss: 3.5391 (3.5138)  loss_ce: 0.5195 (0.5251)  loss_bbox: 0.0940 (0.0928)  loss_giou: 0.5276 (0.5259)  loss_ce_0: 0.5352 (0.5406)  loss_bbox_0: 0.0945 (0.0949)  loss_giou_0: 0.5320 (0.5326)  loss_ce_enc: 0.5469 (0.5497)  loss_bbox_enc: 0.1037 (0.1019)  loss_giou_enc: 0.5569 (0.5503)  loss_ce_unscaled: 0.5195 (0.5251)  class_error_unscaled: 0.7407 (0.9115)  loss_bbox_unscaled: 0.0188 (0.0186)  loss_giou_unscaled: 0.2638 (0.2629)  cardinality_error_unscaled: 278.3750 (278.5119)  loss_ce_0_unscaled: 0.5352 (0.5406)  loss_bbox_0_unscaled: 0.0189 (0.0190)  loss_giou_0_unscaled: 0.2660 (0.2663)  cardinality_error_0_unscaled: 276.3750 (277.1726)  loss_ce_enc_unscaled: 0.5469 (0.5497)  loss_bbox_enc_unscaled: 0.0207 (0.0204)  loss_giou_enc_unscaled: 0.2784 (0.2752)  cardinality_error_enc_unscaled: 277.2500 (277.5298)  time: 0.3104  data: 0.0250  max mem: 5216
# Test:  [21/22]  eta: 0:00:00  class_error: 0.00  loss: 3.5424 (3.5386)  loss_ce: 0.5234 (0.5257)  loss_bbox: 0.0942 (0.0951)  loss_giou: 0.5289 (0.5322)  loss_ce_0: 0.5352 (0.5419)  loss_bbox_0: 0.0974 (0.0965)  loss_giou_0: 0.5390 (0.5387)  loss_ce_enc: 0.5469 (0.5513)  loss_bbox_enc: 0.1037 (0.1029)  loss_giou_enc: 0.5569 (0.5543)  loss_ce_unscaled: 0.5234 (0.5257)  class_error_unscaled: 0.7299 (0.8701)  loss_bbox_unscaled: 0.0188 (0.0190)  loss_giou_unscaled: 0.2644 (0.2661)  cardinality_error_unscaled: 278.2500 (278.1705)  loss_ce_0_unscaled: 0.5352 (0.5419)  loss_bbox_0_unscaled: 0.0195 (0.0193)  loss_giou_0_unscaled: 0.2695 (0.2693)  cardinality_error_0_unscaled: 276.3750 (276.9375)  loss_ce_enc_unscaled: 0.5469 (0.5513)  loss_bbox_enc_unscaled: 0.0207 (0.0206)  loss_giou_enc_unscaled: 0.2784 (0.2771)  cardinality_error_enc_unscaled: 277.1250 (277.3693)  time: 0.3009  data: 0.0242  max mem: 5216
# Test: Total time: 0:00:06 (0.3173 s / it)
# Averaged stats: class_error: 0.00  loss: 3.5424 (3.5386)  loss_ce: 0.5234 (0.5257)  loss_bbox: 0.0942 (0.0951)  loss_giou: 0.5289 (0.5322)  loss_ce_0: 0.5352 (0.5419)  loss_bbox_0: 0.0974 (0.0965)  loss_giou_0: 0.5390 (0.5387)  loss_ce_enc: 0.5469 (0.5513)  loss_bbox_enc: 0.1037 (0.1029)  loss_giou_enc: 0.5569 (0.5543)  loss_ce_unscaled: 0.5234 (0.5257)  class_error_unscaled: 0.7299 (0.8701)  loss_bbox_unscaled: 0.0188 (0.0190)  loss_giou_unscaled: 0.2644 (0.2661)  cardinality_error_unscaled: 278.2500 (278.1705)  loss_ce_0_unscaled: 0.5352 (0.5419)  loss_bbox_0_unscaled: 0.0195 (0.0193)  loss_giou_0_unscaled: 0.2695 (0.2693)  cardinality_error_0_unscaled: 276.3750 (276.9375)  loss_ce_enc_unscaled: 0.5469 (0.5513)  loss_bbox_enc_unscaled: 0.0207 (0.0206)  loss_giou_enc_unscaled: 0.2784 (0.2771)  cardinality_error_enc_unscaled: 277.1250 (277.3693)
# Accumulating evaluation results...
# DONE (t=0.32s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=500 ] = 0.447
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=500 ] = 0.770
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=500 ] = 0.435
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=500 ] = 0.213
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=500 ] = 0.692
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=500 ] = 0.840
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.255
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.507
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=500 ] = 0.521
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=500 ] = 0.297
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=500 ] = 0.748
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=500 ] = 0.870
# Test results: {'class_error': 0.8701005415482954, 'loss': 3.5385537797754463, 'loss_ce': 0.5257457386363636, 'loss_bbox': 0.09512867643074556, 'loss_giou': 0.5321640710939061, 'loss_ce_0': 0.5419034090909091, 'loss_bbox_0': 0.09649446945298802, 'loss_giou_0': 0.5386512387882579, 'loss_ce_enc': 0.5513139204545454, 'loss_bbox_enc': 0.10288280350240794, 'loss_giou_enc': 0.5542694709517739, 'loss_ce_unscaled': 0.5257457386363636, 'class_error_unscaled': 0.8701005415482954, 'loss_bbox_unscaled': 0.01902573521841656, 'loss_giou_unscaled': 0.26608203554695303, 'cardinality_error_unscaled': 278.17045454545456, 'loss_ce_0_unscaled': 0.5419034090909091, 'loss_bbox_0_unscaled': 0.019298894034529276, 'loss_giou_0_unscaled': 0.26932561939412897, 'cardinality_error_0_unscaled': 276.9375, 'loss_ce_enc_unscaled': 0.5513139204545454, 'loss_bbox_enc_unscaled': 0.020576560700481587, 'loss_giou_enc_unscaled': 0.27713473547588696, 'cardinality_error_enc_unscaled': 277.3693181818182, 'results_json': {'class_map': [{'class': 'ball', 'map@50:95': 0.1786535730780784, 'map@50': 0.4009811264413041, 'precision': np.float64(0.7428571428571429), 'recall': np.float64(0.3443708609271523)}, {'class': 'number', 'map@50:95': 0.18064341125520997, 'map@50': 0.5273880161166402, 'precision': np.float64(0.6984402079722704), 'recall': np.float64(0.526797385620915)}, {'class': 'player', 'map@50:95': 0.7043830937543849, 'map@50': 0.9782787544920504, 'precision': np.float64(0.9609817495280051), 'recall': np.float64(0.9573667711598746)}, {'class': 'referee', 'map@50:95': 0.6819438435002432, 'map@50': 0.9504537520224562, 'precision': np.float64(0.9586374695863747), 'recall': np.float64(0.9099307159353349)}, {'class': 'rim', 'map@50:95': 0.4896209002557533, 'map@50': 0.9923854528309974, 'precision': np.float64(0.9817073170731707), 'recall': np.float64(0.9877300613496932)}, {'class': 'all', 'map@50:95': 0.4470489643687339, 'map@50': 0.7698974203806896, 'precision': np.float64(0.8685247774033927), 'recall': np.float64(0.7452391589985939)}], 'map': 0.7698974203806896, 'precision': np.float64(0.8685247774033927), 'recall': np.float64(0.7452391589985939)}, 'coco_eval_bbox': [0.4470489643687339, 0.7698974203806896, 0.43537168932531667, 0.21269731213839776, 0.6922213146681393, 0.8399675786059854, 0.25532328291095113, 0.5071935121549158, 0.5213256167414404, 0.2968430825518902, 0.7481226489574142, 0.8697802197802197]}
# Results saved to output/metrics_plot.png

# %%
from PIL import Image

Image.open("/content/output/metrics_plot.png")
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1800x1200>

# %%
# !ls -la /content/output
# Out:
# total 1774316
# drwxr-xr-x 3 root root      4096 Jan 22 19:33 .
# drwxr-xr-x 1 root root      4096 Jan 22 19:21 ..
# -rw-r--r-- 1 root root 484664813 Jan 22 19:33 checkpoint0009.pth
# -rw-r--r-- 1 root root 362610474 Jan 22 19:33 checkpoint_best_ema.pth
# -rw-r--r-- 1 root root 363841030 Jan 22 19:33 checkpoint_best_regular.pth
# -rw-r--r-- 1 root root 120840095 Jan 22 19:33 checkpoint_best_total.pth
# -rw-r--r-- 1 root root 484655501 Jan 22 19:33 checkpoint.pth
# drwxr-xr-x 2 root root      4096 Jan 22 19:22 eval
# -rw-r--r-- 1 root root      4412 Jan 22 19:33 events.out.tfevents.1769109679.cc039bb6718a.2442.0
# -rw-r--r-- 1 root root     62193 Jan 22 19:33 log.txt
# -rw-r--r-- 1 root root    173403 Jan 22 19:33 metrics_plot.png
# -rw-r--r-- 1 root root      1874 Jan 22 19:33 results.json

# %% [markdown]
# ## Deploy a Trained RF-DETR Model
#
# Deploying to Roboflow allows you to create multi-step computer vision applications that run both in the cloud and your own hardware. Please wait a moment while Roboflow indexes your model.

# %%
model.deploy_to_roboflow(
  workspace="roboflow-jvuqo",
  project_id="basketball-player-detection-2",
  version=13,
  api_key=os.environ["ROBOFLOW_API_KEY"]
)
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# View the status of your deployment at: https://app.roboflow.com/roboflow-jvuqo/basketball-player-detection-2/13
# Share your model with the world at: https://universe.roboflow.com/roboflow-jvuqo/basketball-player-detection-2/model/13

# %% [markdown]
# ## Evaluate Fine-tuned RF-DETR Model

# %% [markdown]
# Before benchmarking the model, we need to load the best saved checkpoint. To ensure it fits on the GPU, we first need to free up GPU memory. This involves deleting any remaining references to previously used objects, triggering Python’s garbage collector, and clearing the CUDA memory cache.

# %%
import gc
import torch
import weakref

def cleanup_gpu_memory(obj=None, verbose: bool = False):

    if not torch.cuda.is_available():
        if verbose:
            print("[INFO] CUDA is not available. No GPU cleanup needed.")
        return

    def get_memory_stats():
        allocated = torch.cuda.memory_allocated()
        reserved = torch.cuda.memory_reserved()
        return allocated, reserved

    torch.cuda.synchronize()

    if verbose:
        alloc, reserv = get_memory_stats()
        print(f"[Before] Allocated: {alloc / 1024**2:.2f} MB | Reserved: {reserv / 1024**2:.2f} MB")

    # Ensure we drop all strong references
    if obj is not None:
        ref = weakref.ref(obj)
        del obj
        if ref() is not None and verbose:
            print("[WARNING] Object not fully garbage collected yet.")

    gc.collect()
    torch.cuda.empty_cache()
    torch.cuda.ipc_collect()

    torch.cuda.synchronize()

    if verbose:
        alloc, reserv = get_memory_stats()
        print(f"[After]  Allocated: {alloc / 1024**2:.2f} MB | Reserved: {reserv / 1024**2:.2f} MB")

# %%
cleanup_gpu_memory(model, verbose=True)
# Out:
# [Before] Allocated: 133.05 MB | Reserved: 5650.00 MB
# [WARNING] Object not fully garbage collected yet.
# [After]  Allocated: 133.05 MB | Reserved: 268.00 MB

# %% [markdown]
# We load the best-performing model from the `checkpoint_best_total.pth` file using the `RFDETRMedium` class. This checkpoint contains the trained weights from our most successful training run. After loading, we call `optimize_for_inference()`, which prepares the model for efficient inference.

# %%
model = RFDETRNano(pretrain_weights="/content/output/checkpoint_best_total.pth")
model.optimize_for_inference()

# %%
import supervision as sv

ds = sv.DetectionDataset.from_coco(
    images_directory_path=f"{dataset.location}/test",
    annotations_path=f"{dataset.location}/test/_annotations.coco.json",
)

# %%
import supervision as sv
from tqdm import tqdm
from supervision.metrics import MeanAveragePrecision

targets = []
predictions = []

for path, image, annotations in tqdm(ds):
    image = Image.open(path)
    detections = model.predict(image, threshold=0)

    targets.append(annotations)
    predictions.append(detections)
# Out:
# 100%|██████████| 169/169 [00:05<00:00, 30.23it/s]

# %%
map_metric = MeanAveragePrecision()
map_result = map_metric.update(predictions, targets).compute()
print(map_result)
# Out:
# Average Precision (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.446
# Average Precision (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.770
# Average Precision (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.436
# Average Precision (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.213
# Average Precision (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.691
# Average Precision (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.842

# %% [markdown]
# ## Run Inference with Fine-tuned RF-DETR Model

# %%
from rfdetr import RFDETRBase
import supervision as sv
from PIL import Image

path, image, annotations = ds[0]
image = Image.open(path)

detections = model.predict(image, threshold=0.5)

text_scale = sv.calculate_optimal_text_scale(resolution_wh=image.size)
thickness = sv.calculate_optimal_line_thickness(resolution_wh=image.size)
color = sv.ColorPalette.from_hex([
    "#ffff00", "#ff9b00", "#ff66ff", "#3399ff", "#ff66b2", "#ff8080",
    "#b266ff", "#9999ff", "#66ffff", "#33ff99", "#66ff66", "#99ff00"
])

bbox_annotator = sv.BoxAnnotator(color=color,thickness=thickness)
label_annotator = sv.LabelAnnotator(
    color=color,
    text_color=sv.Color.BLACK,
    text_scale=text_scale)

annotations_labels = [
    f"{ds.classes[class_id]}"
    for class_id
    in annotations.class_id
]

detections_labels = [
    f"{ds.classes[class_id]} {confidence:.2f}"
    for class_id, confidence
    in zip(detections.class_id, detections.confidence)
]

annotation_image = image.copy()
annotation_image = bbox_annotator.annotate(annotation_image, annotations)
annotation_image = label_annotator.annotate(annotation_image, annotations, annotations_labels)

detections_image = image.copy()
detections_image = bbox_annotator.annotate(detections_image, detections)
detections_image = label_annotator.annotate(detections_image, detections, detections_labels)

sv.plot_images_grid(images=[annotation_image, detections_image], grid_size=(1, 2), titles=["Annotation", "Detection"])

# %%
# !pip install -q inference

# %%
from inference import get_model

MODEL_ID = "basketball-player-detection-2/13"
model_rf = get_model(model_id=MODEL_ID, api_key = userdata.get("ROBOFLOW_API_KEY"))

# %%
import supervision as sv
from PIL import Image

path, image, annotations = ds[0]
image = Image.open(path)

result = model_rf.infer(image, confidence=0.3)[0]
detections = sv.Detections.from_inference(result)

text_scale = sv.calculate_optimal_text_scale(resolution_wh=image.size)
thickness = sv.calculate_optimal_line_thickness(resolution_wh=image.size)
color = sv.ColorPalette.from_hex([
    "#ffff00", "#ff9b00", "#ff66ff", "#3399ff", "#ff66b2", "#ff8080",
    "#b266ff", "#9999ff", "#66ffff", "#33ff99", "#66ff66", "#99ff00"
])

bbox_annotator = sv.BoxAnnotator(color=color,thickness=thickness)
label_annotator = sv.LabelAnnotator(
    color=color,
    text_color=sv.Color.BLACK,
    text_scale=text_scale)

annotations_labels = [
    f"{ds.classes[class_id]}"
    for class_id
    in annotations.class_id
]

annotation_image = image.copy()
annotation_image = bbox_annotator.annotate(annotation_image, annotations)
annotation_image = label_annotator.annotate(annotation_image, annotations, annotations_labels)

detections_image = image.copy()
detections_image = bbox_annotator.annotate(detections_image, detections)
detections_image = label_annotator.annotate(detections_image, detections)

sv.plot_images_grid(images=[annotation_image, detections_image], grid_size=(1, 2), titles=["Annotation", "Detection"])

# %% [markdown]
# <div align="center">
#   <p>
#     Looking for more tutorials or have questions?
#     Check out our <a href="https://github.com/roboflow/notebooks">GitHub repo</a> for more notebooks,
#     or visit our <a href="https://discord.gg/GbfgXGJ8Bk">discord</a>.
#   </p>
#
#   <p>
#     <strong>If you found this helpful, please consider giving us a ⭐
#     <a href="https://github.com/roboflow/notebooks">on GitHub</a>!</strong>
#   </p>
#
# </div>
